# %% [markdown]
# # <center>Web Scraping by API </center>

# %% [markdown]
# ## 1. Scrape data through APIs
# - Online content providers usually provide APIs for you to access data. Two types of APIs:
#    * Python packages: e.g. tweepy package from Twitter
#    * REST APIs: e.g. OMDB APIs (http://www.omdbapi.com), or TMDB (https://developers.themoviedb.org/3/getting-started)
# - You need to read documentation of APIs to figure out how to access data

# %% [markdown]
# ## 2. Scrape data by REST APIs (e.g. OMDB API)
# - A REST API is a web service that uses `HTTP` requests to `GET`, `PUT`, `POST` and `DELETE` data
# - Example:
#     - https://groceries.asda.com/api/items/search<font color="blue"><b>?</b></font><font color='green'><b>keyword</b></font>=<font color='red'><b>yogurt<b></font><front color='purple'><b>&</b></font><font color='green'><b>r</b></font>=<font color='red'><b>json<b></font>, where
#         - `?`: separate API endpoint  `https://groceries.asda.com/api/items/search` from parameters
#         - `keyword=yogurt`: search `yogurt` on parameter `keyword`
#         - `&`: combine multiple search criteria
#         - `r=json`: result is in json format
#     - You can directly paste the above API to your browser
#     - Or issue API calls using requests
# - You need to read API documentation to understand how to specify parameters

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import requests
import json
import pandas as pd

# %%
import requests
import json

keyword = 'yogurt'


url="https://groceries.asda.com/api/items/search?keyword=" + keyword + "&r=json"

print(url)

# invoke the API 
r = requests.get(url)

# if the API call returns a successful response
if r.status_code==200:
    
    # This API call returns a json object
    # r.json() gives the json object
    # json. dumps() function converts a Python object into a json string
    result = r.json()
    print (json.dumps(result, indent=4))
# Out:
# https://groceries.asda.com/api/items/search?keyword=yogurt&r=json
# {
#     "statusMessage": "The API Item Search was executed successfully",
#     "errors": [],
#     "keyword": "yogurt",
#     "storeId": "4565",
#     "autoCorrectedTerm": "",
#     "didYouMeanTerm": "",
#     "isHookLogicInsert": "false",
#     "totalResult": "435",
#     "currentPage": "1",
#     "resultsStartIndex": "1",
#     "resultsEndIndex": "60",
#     "maxPages": "8",
#     "qusApplied": false,
#     "productBoostingDetails": "0^rule_613f0638f04fd127608474cd^^^Default",
#     "monetizedItems": [],
#     "items": [
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368400",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "18",
#             "asdaSuggest": "",
#             "itemName": "Corner Vanilla Yogurt with Chocolate Balls",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031656",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277031",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7222",
#             "name": "Muller Corner Vanilla Yogurt with Chocolate Balls",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031656",
#             "pricePerUOM": "",
#             "searchTuningScore": "4390417.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368408",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "18",
#             "asdaSuggest": "",
#             "itemName": "Corner Strawberry Yogurt",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031677",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "136g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277239",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6111",
#             "name": "Muller Corner Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031677",
#             "pricePerUOM": "",
#             "searchTuningScore": "4268856.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368402",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "19",
#             "asdaSuggest": "",
#             "itemName": "Corner Banana Yogurt with Chocolate Flakes",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031660",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277055",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7895",
#             "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031660",
#             "pricePerUOM": "",
#             "searchTuningScore": "3510444.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7367121",
#             "promoDetailFull": "3 for \u00a32.00",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Dairy Milk Buttons Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000376780232",
#             "promoId": "ls92846",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "75g       ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278366",
#             "promoDetail": "3 for \u00a32.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.75",
#             "name": "Cadbury Dairy Milk Buttons Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780232",
#             "pricePerUOM": "",
#             "searchTuningScore": "1711667.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346354",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "23",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808369",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243357",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4783",
#             "name": "Muller Light Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808369",
#             "pricePerUOM": "",
#             "searchTuningScore": "1584629.1",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346362",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "28",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Toffee Yogurt",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808315",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243579",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5714",
#             "name": "Muller Light Fat Free Toffee Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808315",
#             "pricePerUOM": "",
#             "searchTuningScore": "1581345.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346360",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "26",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Banana and Custard Yogurt",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808339",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243555",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1154",
#             "name": "Muller Light Fat Free Banana and Custard Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808339",
#             "pricePerUOM": "",
#             "searchTuningScore": "1339746.6",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7367119",
#             "promoDetailFull": "3 for \u00a32.00",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Flake Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000376780395",
#             "promoId": "ls92846",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "75g       ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278342",
#             "promoDetail": "3 for \u00a32.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4167",
#             "name": "Cadbury Flake Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780395",
#             "pricePerUOM": "",
#             "searchTuningScore": "1211385.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6202233",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "45",
#             "asdaSuggest": "",
#             "itemName": "Vanilla & Granola Breakfast Pot low fat yoghurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078311452",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360502960",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3778",
#             "name": "Activia Vanilla & Granola Breakfast Pot low fat yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#             "pricePerUOM": "",
#             "searchTuningScore": "1124578.6",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a35::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "1044649",
#             "promoDetailFull": "2 for \u00a35",
#             "availability": "A",
#             "totalReviewCount": "179",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Cultured Yoghurt Drink",
#             "price": "\u00a33.00",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "976012",
#             "promoId": "ls92774",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Actimel",
#             "promoType": "No Promo",
#             "weight": "8x100g    ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a35",
#             "productAttribute": "",
#             "scene7AssetId": "5410146407024",
#             "promoDetail": "2 for \u00a35",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5754",
#             "name": "Actimel Strawberry Cultured Yoghurt Drink",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=976012",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.166667",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3638102",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "29",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Vanilla Yogurts",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000446045",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.80",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453674",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7241",
#             "name": "Munch Bunch Double Up Strawberry & Vanilla Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000446045",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.164345",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -1
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6525307",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "40",
#             "asdaSuggest": "",
#             "itemName": "Kvarg White Chocolate",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000164970300",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290037577",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.125",
#             "name": "Lindahls Kvarg White Chocolate",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000164970300",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.098993",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 1
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006850",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "79",
#             "asdaSuggest": "",
#             "itemName": "Rhubarb Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290068820",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.30",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506166",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5949",
#             "name": "Activia Rhubarb Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068820",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.08806",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 6
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6041536",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "36",
#             "asdaSuggest": "",
#             "itemName": "Kvarg Raspberry",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000023135121",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290018354",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0833",
#             "name": "Lindahls Kvarg Raspberry",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000023135121",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.082517",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006848",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "47",
#             "asdaSuggest": "",
#             "itemName": "Peach No Added Sugar Fat Free Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290067858",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.30",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506203",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6383",
#             "name": "Activia Peach No Added Sugar Fat Free Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290067858",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.080933",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a35::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "1666628",
#             "promoDetailFull": "2 for \u00a35",
#             "availability": "A",
#             "totalReviewCount": "109",
#             "asdaSuggest": "",
#             "itemName": "Strawberry 0% Added Sugar Fat Free Yoghurt Drink",
#             "price": "\u00a33.00",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "6979691",
#             "promoId": "ls92774",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Actimel",
#             "promoType": "No Promo",
#             "weight": "8x100g    ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a35",
#             "productAttribute": "",
#             "scene7AssetId": "5060058332152",
#             "promoDetail": "2 for \u00a35",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4495",
#             "name": "Actimel Strawberry 0% Added Sugar Fat Free Yoghurt Drink",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=6979691",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.077225",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 9
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346374",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "44",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Limited Edition Yogurt",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808405",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243715",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.9545",
#             "name": "Muller Light Fat Free Limited Edition Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808405",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.068845",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -5
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368406",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "O",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Corner Toffee Yogurt with Chocolate Hoops",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031761",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "true",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277116",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6667",
#             "name": "Muller Corner Toffee Yogurt with Chocolate Hoops",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031761",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.068765",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -7
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6744528",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Smarties Vanilla Flavour Yogurt 6x107g",
#             "price": "\u00a32.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000226920884",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Nestle",
#             "promoType": "Rollback",
#             "weight": "6x107g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290045053",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2857",
#             "name": "Nestle Smarties Vanilla Flavour Yogurt 6x107g",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000226920884",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.068685",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 11
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4776662",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "93",
#             "asdaSuggest": "",
#             "itemName": "Yollies Strawberry Yogurt Lollies",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001451015",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.75",
#             "brandName": "Strings & Things",
#             "promoType": "Rollback",
#             "weight": "4x25g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5010252108084",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.3871",
#             "name": "Strings & Things Yollies Strawberry Yogurt Lollies",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001451015",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.064693",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -3
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006854",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "49",
#             "asdaSuggest": "",
#             "itemName": "Strawberry No Added Sugar Fat Free Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290068276",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.30",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506289",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6531",
#             "name": "Activia Strawberry No Added Sugar Fat Free Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068276",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.063922",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3638100",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Banana Yogurts",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000446282",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.80",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453667",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5",
#             "name": "Munch Bunch Double Up Strawberry & Banana Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000446282",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.063784",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 2
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6041538",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "18",
#             "asdaSuggest": "",
#             "itemName": "Kvarg Vanilla",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000023135046",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290018415",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3333",
#             "name": "Lindahls Kvarg Vanilla",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000023135046",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.063578",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -2
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6041546",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "47",
#             "asdaSuggest": "",
#             "itemName": "Cheesecake Inspired Whipped Greek Style Salted Caramel Yogurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000023135303",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.25",
#             "brandName": "Muller Corner Bliss",
#             "promoType": "Rollback",
#             "weight": "4x100g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500227722",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4255",
#             "name": "Muller Corner Bliss Cheesecake Inspired Whipped Greek Style Salted Caramel Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000023135303",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.062633",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 3
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6513082",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "78",
#             "asdaSuggest": "",
#             "itemName": "Raspberry & Chia Seed Museli Breakfast Pot Low fat yoghurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000161156362",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360504360",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6923",
#             "name": "Activia Raspberry & Chia Seed Museli Breakfast Pot Low fat yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000161156362",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.058358",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -7
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346366",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "23",
#             "asdaSuggest": "",
# ...
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5010252108107",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.4118",
#             "name": "Strings & Things Yollies Raspberry Yogurt Lollies",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001450265",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.027077",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -4
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786444",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "47",
#             "asdaSuggest": "",
#             "itemName": "Apricot & Strawberry Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458398",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.75",
#             "brandName": "Petits Filous",
#             "promoType": "Rollback",
#             "weight": "4x85g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051577",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4043",
#             "name": "Petits Filous Apricot & Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458398",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.026565",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -7
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786442",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "90",
#             "asdaSuggest": "",
#             "itemName": "Raspberry & Strawberry Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458097",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.75",
#             "brandName": "Petits Filous",
#             "promoType": "Rollback",
#             "weight": "4x85g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051584",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2778",
#             "name": "Petits Filous Raspberry & Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458097",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.025877",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -7
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7296508",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Pro + Kvarg Banoffee Pie",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000359006880",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290062777",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Lindahls Pro + Kvarg Banoffee Pie",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000359006880",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.025585",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -14
#         },
#         {
#             "shelfId": "1215286439451",
#             "shelfName": "Natural & Greek",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5035968",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "61",
#             "asdaSuggest": "",
#             "itemName": "Natural Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001817523",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.85",
#             "brandName": "Arla Skyr",
#             "promoType": "Rollback",
#             "weight": "450g      ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4016241030573",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6393",
#             "name": "Arla Skyr Natural Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "1215559958453",
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001817523",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.02423",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -4
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7366589",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Little Yeos Organic No Added Sugar Mango, Vanilla and Blueberry, Banana Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000376780465",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Yeo Valley",
#             "promoType": "Rollback",
#             "weight": "6x42g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5036589254553",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5714",
#             "name": "Yeo Valley Little Yeos Organic No Added Sugar Mango, Vanilla and Blueberry, Banana Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600066"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780465",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.022365",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -8
#         },
#         {
#             "shelfId": "1215686351335",
#             "shelfName": "Organic Yogurts & Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7039823",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "6",
#             "asdaSuggest": "",
#             "itemName": "Organic Lemon Curd Creamy Bio Live Yogurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Organic Yogurts & Desserts",
#             "id": "1000298097150",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.95",
#             "brandName": "Yeo Valley",
#             "promoType": "Rollback",
#             "weight": "450g      ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5036589204121",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3333",
#             "name": "Yeo Valley Organic Lemon Curd Creamy Bio Live Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600066"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000298097150",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.02068",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -4
#         }
#     ],
#     "facets": [
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Chilled Food",
#             "displayName": "Chilled Food",
#             "itemCount": "354"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Free From...",
#             "displayName": "Free From...",
#             "itemCount": "22"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Baby, Toddler & Kids",
#             "displayName": "Baby, Toddler & Kids",
#             "itemCount": "17"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Bakery",
#             "displayName": "Bakery",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Food Cupboard",
#             "displayName": "Food Cupboard",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Drinks",
#             "displayName": "Drinks",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:World & Local Food",
#             "displayName": "World & Local Food",
#             "itemCount": "4"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Toiletries & Beauty",
#             "displayName": "Toiletries & Beauty",
#             "itemCount": "2"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Meat, Poultry & Fish",
#             "displayName": "Meat, Poultry & Fish",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Pet Food & Accessories",
#             "displayName": "Pet Food & Accessories",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA",
#             "displayName": "ASDA",
#             "itemCount": "56"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller",
#             "displayName": "Muller",
#             "itemCount": "23"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Activia",
#             "displayName": "Activia",
#             "itemCount": "17"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Yeo Valley",
#             "displayName": "Yeo Valley",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA Extra Special",
#             "displayName": "ASDA Extra Special",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Actimel",
#             "displayName": "Actimel",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Lindahls",
#             "displayName": "Lindahls",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Alpro",
#             "displayName": "Alpro",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Biotiful",
#             "displayName": "Biotiful",
#             "itemCount": "9"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Light & Free",
#             "displayName": "Light & Free",
#             "itemCount": "9"
#         }
#     ],
#     "mediaContent": "",
#     "useKeywordAsIcon": "",
#     "processTime": 89,
#     "statusCode": "0"
# }

# %%
# Exercise 2.2.  Another way to pass parameters

parameters = {'keyword': 'yogurt', 
              'r': 'json'}

r=requests.get('https://groceries.asda.com/api/items/search', params=parameters)

# in case authentication is needed, use
# r = requests.get('https://api.github.com/user', \
# auth=('user', 'pass'))

# if the API call returns a successful response
if r.status_code==200:
    
    # This API call returns a json object
    # r.json() gives the json object
    print (json.dumps(r.json(), indent=4))
# Out:
# {
#     "statusMessage": "The API Item Search was executed successfully",
#     "errors": [],
#     "keyword": "yogurt",
#     "storeId": "4565",
#     "autoCorrectedTerm": "",
#     "didYouMeanTerm": "",
#     "isHookLogicInsert": "false",
#     "totalResult": "435",
#     "currentPage": "1",
#     "resultsStartIndex": "1",
#     "resultsEndIndex": "60",
#     "maxPages": "8",
#     "qusApplied": false,
#     "productBoostingDetails": "0^rule_613f0638f04fd127608474cd^^^Default",
#     "monetizedItems": [],
#     "items": [
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368400",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "18",
#             "asdaSuggest": "",
#             "itemName": "Corner Vanilla Yogurt with Chocolate Balls",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031656",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277031",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7222",
#             "name": "Muller Corner Vanilla Yogurt with Chocolate Balls",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031656",
#             "pricePerUOM": "",
#             "searchTuningScore": "4390417.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368408",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "18",
#             "asdaSuggest": "",
#             "itemName": "Corner Strawberry Yogurt",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031677",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "136g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277239",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6111",
#             "name": "Muller Corner Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031677",
#             "pricePerUOM": "",
#             "searchTuningScore": "4268856.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368402",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "19",
#             "asdaSuggest": "",
#             "itemName": "Corner Banana Yogurt with Chocolate Flakes",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031660",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277055",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7895",
#             "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031660",
#             "pricePerUOM": "",
#             "searchTuningScore": "3510444.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7367121",
#             "promoDetailFull": "3 for \u00a32.00",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Dairy Milk Buttons Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000376780232",
#             "promoId": "ls92846",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "75g       ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278366",
#             "promoDetail": "3 for \u00a32.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.75",
#             "name": "Cadbury Dairy Milk Buttons Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780232",
#             "pricePerUOM": "",
#             "searchTuningScore": "1711667.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346354",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "23",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808369",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243357",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4783",
#             "name": "Muller Light Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808369",
#             "pricePerUOM": "",
#             "searchTuningScore": "1584629.1",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346362",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "28",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Toffee Yogurt",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808315",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243579",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5714",
#             "name": "Muller Light Fat Free Toffee Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808315",
#             "pricePerUOM": "",
#             "searchTuningScore": "1581345.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346360",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "26",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Banana and Custard Yogurt",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808339",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243555",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1154",
#             "name": "Muller Light Fat Free Banana and Custard Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808339",
#             "pricePerUOM": "",
#             "searchTuningScore": "1339746.6",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7367119",
#             "promoDetailFull": "3 for \u00a32.00",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Flake Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000376780395",
#             "promoId": "ls92846",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "75g       ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278342",
#             "promoDetail": "3 for \u00a32.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4167",
#             "name": "Cadbury Flake Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780395",
#             "pricePerUOM": "",
#             "searchTuningScore": "1211385.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6202233",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "45",
#             "asdaSuggest": "",
#             "itemName": "Vanilla & Granola Breakfast Pot low fat yoghurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078311452",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360502960",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3778",
#             "name": "Activia Vanilla & Granola Breakfast Pot low fat yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#             "pricePerUOM": "",
#             "searchTuningScore": "1124578.6",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a35::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "1044649",
#             "promoDetailFull": "2 for \u00a35",
#             "availability": "A",
#             "totalReviewCount": "179",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Cultured Yoghurt Drink",
#             "price": "\u00a33.00",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "976012",
#             "promoId": "ls92774",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Actimel",
#             "promoType": "No Promo",
#             "weight": "8x100g    ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a35",
#             "productAttribute": "",
#             "scene7AssetId": "5410146407024",
#             "promoDetail": "2 for \u00a35",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5754",
#             "name": "Actimel Strawberry Cultured Yoghurt Drink",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=976012",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.166667",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3638102",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "29",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Vanilla Yogurts",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000446045",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.80",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453674",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7241",
#             "name": "Munch Bunch Double Up Strawberry & Vanilla Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000446045",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.164345",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -1
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6525307",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "40",
#             "asdaSuggest": "",
#             "itemName": "Kvarg White Chocolate",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000164970300",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290037577",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.125",
#             "name": "Lindahls Kvarg White Chocolate",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000164970300",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.098993",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 1
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006850",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "79",
#             "asdaSuggest": "",
#             "itemName": "Rhubarb Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290068820",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.30",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506166",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5949",
#             "name": "Activia Rhubarb Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068820",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.08806",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 6
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6041536",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "36",
#             "asdaSuggest": "",
#             "itemName": "Kvarg Raspberry",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000023135121",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290018354",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0833",
#             "name": "Lindahls Kvarg Raspberry",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000023135121",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.082517",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006848",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "47",
#             "asdaSuggest": "",
#             "itemName": "Peach No Added Sugar Fat Free Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290067858",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.30",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506203",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6383",
#             "name": "Activia Peach No Added Sugar Fat Free Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290067858",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.080933",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a35::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "1666628",
#             "promoDetailFull": "2 for \u00a35",
#             "availability": "A",
#             "totalReviewCount": "109",
#             "asdaSuggest": "",
#             "itemName": "Strawberry 0% Added Sugar Fat Free Yoghurt Drink",
#             "price": "\u00a33.00",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "6979691",
#             "promoId": "ls92774",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Actimel",
#             "promoType": "No Promo",
#             "weight": "8x100g    ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a35",
#             "productAttribute": "",
#             "scene7AssetId": "5060058332152",
#             "promoDetail": "2 for \u00a35",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4495",
#             "name": "Actimel Strawberry 0% Added Sugar Fat Free Yoghurt Drink",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=6979691",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.077225",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 9
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346374",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "44",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Limited Edition Yogurt",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808405",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243715",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.9545",
#             "name": "Muller Light Fat Free Limited Edition Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808405",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.068845",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -5
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368406",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "O",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Corner Toffee Yogurt with Chocolate Hoops",
#             "price": "\u00a30.70",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031761",
#             "promoId": "ls92759",
#             "isFavourite": "false",
#             "hasAlternates": "true",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277116",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6667",
#             "name": "Muller Corner Toffee Yogurt with Chocolate Hoops",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031761",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.068765",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -7
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6744528",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Smarties Vanilla Flavour Yogurt 6x107g",
#             "price": "\u00a32.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000226920884",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Nestle",
#             "promoType": "Rollback",
#             "weight": "6x107g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290045053",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2857",
#             "name": "Nestle Smarties Vanilla Flavour Yogurt 6x107g",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000226920884",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.068685",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 11
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4776662",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "93",
#             "asdaSuggest": "",
#             "itemName": "Yollies Strawberry Yogurt Lollies",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001451015",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.75",
#             "brandName": "Strings & Things",
#             "promoType": "Rollback",
#             "weight": "4x25g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5010252108084",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.3871",
#             "name": "Strings & Things Yollies Strawberry Yogurt Lollies",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001451015",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.064693",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -3
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006854",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "49",
#             "asdaSuggest": "",
#             "itemName": "Strawberry No Added Sugar Fat Free Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290068276",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.30",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506289",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6531",
#             "name": "Activia Strawberry No Added Sugar Fat Free Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068276",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.063922",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3638100",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Banana Yogurts",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000446282",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.80",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453667",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5",
#             "name": "Munch Bunch Double Up Strawberry & Banana Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000446282",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.063784",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 2
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6041538",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "18",
#             "asdaSuggest": "",
#             "itemName": "Kvarg Vanilla",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000023135046",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290018415",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3333",
#             "name": "Lindahls Kvarg Vanilla",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000023135046",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.063578",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -2
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6041546",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "47",
#             "asdaSuggest": "",
#             "itemName": "Cheesecake Inspired Whipped Greek Style Salted Caramel Yogurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000023135303",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.25",
#             "brandName": "Muller Corner Bliss",
#             "promoType": "Rollback",
#             "weight": "4x100g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500227722",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4255",
#             "name": "Muller Corner Bliss Cheesecake Inspired Whipped Greek Style Salted Caramel Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000023135303",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.062633",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 3
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6513082",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "78",
#             "asdaSuggest": "",
#             "itemName": "Raspberry & Chia Seed Museli Breakfast Pot Low fat yoghurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000161156362",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360504360",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6923",
#             "name": "Activia Raspberry & Chia Seed Museli Breakfast Pot Low fat yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000161156362",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.058358",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -7
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346366",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "23",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Vanilla & Dark Chocolate Yogurt",
# ...
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5010252108107",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.4118",
#             "name": "Strings & Things Yollies Raspberry Yogurt Lollies",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001450265",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.027077",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -4
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786444",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "47",
#             "asdaSuggest": "",
#             "itemName": "Apricot & Strawberry Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458398",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.75",
#             "brandName": "Petits Filous",
#             "promoType": "Rollback",
#             "weight": "4x85g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051577",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4043",
#             "name": "Petits Filous Apricot & Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458398",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.026565",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -7
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786442",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "90",
#             "asdaSuggest": "",
#             "itemName": "Raspberry & Strawberry Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458097",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.75",
#             "brandName": "Petits Filous",
#             "promoType": "Rollback",
#             "weight": "4x85g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051584",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2778",
#             "name": "Petits Filous Raspberry & Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458097",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.025877",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -7
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7296508",
#             "promoDetailFull": "4 for \u00a33.00",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Pro + Kvarg Banoffee Pie",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000359006880",
#             "promoId": "ls92838",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290062777",
#             "promoDetail": "4 for \u00a33.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Lindahls Pro + Kvarg Banoffee Pie",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000359006880",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.025585",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -14
#         },
#         {
#             "shelfId": "1215286439451",
#             "shelfName": "Natural & Greek",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5035968",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "61",
#             "asdaSuggest": "",
#             "itemName": "Natural Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001817523",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.85",
#             "brandName": "Arla Skyr",
#             "promoType": "Rollback",
#             "weight": "450g      ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4016241030573",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6393",
#             "name": "Arla Skyr Natural Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "1215559958453",
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001817523",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.02423",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -4
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7366589",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Little Yeos Organic No Added Sugar Mango, Vanilla and Blueberry, Banana Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000376780465",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Yeo Valley",
#             "promoType": "Rollback",
#             "weight": "6x42g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5036589254553",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5714",
#             "name": "Yeo Valley Little Yeos Organic No Added Sugar Mango, Vanilla and Blueberry, Banana Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600066"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780465",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.022365",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -8
#         },
#         {
#             "shelfId": "1215686351335",
#             "shelfName": "Organic Yogurts & Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7039823",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "6",
#             "asdaSuggest": "",
#             "itemName": "Organic Lemon Curd Creamy Bio Live Yogurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Organic Yogurts & Desserts",
#             "id": "1000298097150",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.95",
#             "brandName": "Yeo Valley",
#             "promoType": "Rollback",
#             "weight": "450g      ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5036589204121",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3333",
#             "name": "Yeo Valley Organic Lemon Curd Creamy Bio Live Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600066"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000298097150",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.02068",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -4
#         }
#     ],
#     "facets": [
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Chilled Food",
#             "displayName": "Chilled Food",
#             "itemCount": "354"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Free From...",
#             "displayName": "Free From...",
#             "itemCount": "22"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Baby, Toddler & Kids",
#             "displayName": "Baby, Toddler & Kids",
#             "itemCount": "17"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Bakery",
#             "displayName": "Bakery",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Food Cupboard",
#             "displayName": "Food Cupboard",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Drinks",
#             "displayName": "Drinks",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:World & Local Food",
#             "displayName": "World & Local Food",
#             "itemCount": "4"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Toiletries & Beauty",
#             "displayName": "Toiletries & Beauty",
#             "itemCount": "2"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Meat, Poultry & Fish",
#             "displayName": "Meat, Poultry & Fish",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Pet Food & Accessories",
#             "displayName": "Pet Food & Accessories",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA",
#             "displayName": "ASDA",
#             "itemCount": "56"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller",
#             "displayName": "Muller",
#             "itemCount": "23"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Activia",
#             "displayName": "Activia",
#             "itemCount": "17"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Yeo Valley",
#             "displayName": "Yeo Valley",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA Extra Special",
#             "displayName": "ASDA Extra Special",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Actimel",
#             "displayName": "Actimel",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Lindahls",
#             "displayName": "Lindahls",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Alpro",
#             "displayName": "Alpro",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Biotiful",
#             "displayName": "Biotiful",
#             "itemCount": "9"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Light & Free",
#             "displayName": "Light & Free",
#             "itemCount": "9"
#         }
#     ],
#     "mediaContent": "",
#     "useKeywordAsIcon": "",
#     "processTime": 74,
#     "statusCode": "0"
# }

# %% [markdown]
# ## 3. JSON (JavaScript Object Notation)
#
# ### What is JSON
# - A lightweight data-interchange format
# - "Self-describing" and easy to understand
# - JSON format is text only
# - Language independent: can be read and used as a data format by any programming language
#
# ###  JSON Syntax Rules
# JSON syntax is derived from JavaScript object notation syntax:
# - Data is in **name/value** pairs separated by commas
# - Curly braces hold objects
# - Square brackets hold arrays
#
# ### A JSON object is:
# - **a dictionary** or
# - a **list of dictionaries**
#
# ### Useful JSON functions
# - dumps: save json object to string
# - dump: save json object to file
# - loads: load from a string in json format
# - load: load from a file in json format

# %%
# Exercise 3.1 API returns a JSON object 

parameters = {'keyword': 'yogurt', 
              'r': 'json'}

r=requests.get('https://groceries.asda.com/api/items/search', params=parameters)

# if the API call returns a successful response
if r.status_code==200:
    result = r.json()
    
    df = pd.DataFrame(result["items"])
    df.head()
# Out:
#          shelfId                       shelfName         deptId  \
# 0  1215286383583                         Corners  1215341888021
# 1  1215286383583                         Corners  1215341888021
# 2  1215286383583                         Corners  1215341888021
# 3  1215639170517    Chocolate & Caramel Desserts  1215341888021
# 4   910000977060  Diet, Low Fat & No Added Sugar  1215341888021
#
#              deptName isBundle  meatStickerDetails extraLargeImageURL  \
# 0  Yogurts & Desserts    false  10::for::£4::false
# 1  Yogurts & Desserts    false  10::for::£4::false
# 2  Yogurts & Desserts    false  10::for::£4::false
# 3  Yogurts & Desserts    false   3::for::£2::false
# 4  Yogurts & Desserts    false  10::for::£4::false
#
#   bundledItemCount                          scene7Host      cin  ...  \
# 0                0  https://ui.assets-asda.com:443/dm/  7368400  ...
# 1                0  https://ui.assets-asda.com:443/dm/  7368408  ...
# 2                0  https://ui.assets-asda.com:443/dm/  7368402  ...
# 3                0  https://ui.assets-asda.com:443/dm/  7367121  ...
# 4                0  https://ui.assets-asda.com:443/dm/  6346354  ...
#
#   avgWeight                                        iconDetails maxQty  \
# 0                                                           {}   10.0
# 1                                                           {}   10.0
# 2                                                           {}   10.0
# 3                                                           {}   10.0
# 4            {'promotionalIcons': ['59600051'], 'informatio...   10.0
#
#   pricePerWt                                         productURL pricePerUOM  \
# 0       Each  https://groceries.asda.com:443/api/items/view?...
# 1       Each  https://groceries.asda.com:443/api/items/view?...
# 2       Each  https://groceries.asda.com:443/api/items/view?...
# 3       Each  https://groceries.asda.com:443/api/items/view?...
# 4       Each  https://groceries.asda.com:443/api/items/view?...
#
#   searchTuningScore onSale salePrice positionChngByMargin
# 0         4390417.0  False                              0
# 1         4268856.5  False                              0
# 2         3510444.8  False                              0
# 3         1711667.0  False                              0
# 4         1584629.1  False                              0
#
# [5 rows x 45 columns]

# %%
# Exercise 3.2. Parse JSON object (a dictionary)

# convert the first 2 items to string
s = json.dumps(result["items"][0:2], indent=4)
print(s)

# load back from a string
items = json.loads(s)
items

# save to file
json.dump(result["items"], open("items.json","w"))

# load back from file
items = json.load(open("items.json","r"))
print("test loaded data\n")
len(items)
items[0]
# Out:
# [
#     {
#         "shelfId": "1215286383583",
#         "shelfName": "Corners",
#         "deptId": "1215341888021",
#         "deptName": "Yogurts & Desserts",
#         "isBundle": "false",
#         "meatStickerDetails": "10::for::\u00a34::false",
#         "extraLargeImageURL": "",
#         "bundledItemCount": "0",
#         "scene7Host": "https://ui.assets-asda.com:443/dm/",
#         "cin": "7368400",
#         "promoDetailFull": "10 for \u00a34",
#         "availability": "A",
#         "totalReviewCount": "18",
#         "asdaSuggest": "",
#         "itemName": "Corner Vanilla Yogurt with Chocolate Balls",
#         "price": "\u00a30.70",
#         "imageURL": "",
#         "aisleName": "Yogurts & Fromage Frais",
#         "id": "1000377031656",
#         "promoId": "ls92759",
#         "isFavourite": "false",
#         "hasAlternates": "false",
#         "wasPrice": "",
#         "brandName": "Muller",
#         "promoType": "No Promo",
#         "weight": "124g      ",
#         "promoOfferTypeCode": "15",
#         "promoQty": "10",
#         "promoValue": "\u00a34",
#         "productAttribute": "",
#         "scene7AssetId": "4025500277031",
#         "promoDetail": "10 for \u00a34",
#         "bundleDiscount": "0.00",
#         "avgStarRating": "4.7222",
#         "name": "Muller Corner Vanilla Yogurt with Chocolate Balls",
#         "avgWeight": "",
#         "iconDetails": {},
#         "maxQty": "10.0",
#         "pricePerWt": "Each",
#         "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031656",
#         "pricePerUOM": "",
#         "searchTuningScore": "4390417.0",
#         "onSale": false,
#         "salePrice": "",
#         "positionChngByMargin": 0
#     },
#     {
#         "shelfId": "1215286383583",
#         "shelfName": "Corners",
#         "deptId": "1215341888021",
#         "deptName": "Yogurts & Desserts",
#         "isBundle": "false",
#         "meatStickerDetails": "10::for::\u00a34::false",
#         "extraLargeImageURL": "",
#         "bundledItemCount": "0",
#         "scene7Host": "https://ui.assets-asda.com:443/dm/",
#         "cin": "7368408",
#         "promoDetailFull": "10 for \u00a34",
#         "availability": "A",
#         "totalReviewCount": "18",
#         "asdaSuggest": "",
#         "itemName": "Corner Strawberry Yogurt",
#         "price": "\u00a30.70",
#         "imageURL": "",
#         "aisleName": "Yogurts & Fromage Frais",
#         "id": "1000377031677",
#         "promoId": "ls92759",
#         "isFavourite": "false",
#         "hasAlternates": "false",
#         "wasPrice": "",
#         "brandName": "Muller",
#         "promoType": "No Promo",
#         "weight": "136g      ",
#         "promoOfferTypeCode": "15",
#         "promoQty": "10",
#         "promoValue": "\u00a34",
#         "productAttribute": "",
#         "scene7AssetId": "4025500277239",
#         "promoDetail": "10 for \u00a34",
#         "bundleDiscount": "0.00",
#         "avgStarRating": "4.6111",
#         "name": "Muller Corner Strawberry Yogurt",
#         "avgWeight": "",
#         "iconDetails": {},
#         "maxQty": "10.0",
#         "pricePerWt": "Each",
#         "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031677",
#         "pricePerUOM": "",
#         "searchTuningScore": "4268856.5",
#         "onSale": false,
#         "salePrice": "",
#         "positionChngByMargin": 0
#     }
# ]
# [{'shelfId': '1215286383583',
#   'shelfName': 'Corners',
#   'deptId': '1215341888021',
#   'deptName': 'Yogurts & Desserts',
#   'isBundle': 'false',
#   'meatStickerDetails': '10::for::£4::false',
#   'extraLargeImageURL': '',
#   'bundledItemCount': '0',
#   'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#   'cin': '7368400',
#   'promoDetailFull': '10 for £4',
#   'availability': 'A',
#   'totalReviewCount': '18',
#   'asdaSuggest': '',
#   'itemName': 'Corner Vanilla Yogurt with Chocolate Balls',
#   'price': '£0.70',
#   'imageURL': '',
#   'aisleName': 'Yogurts & Fromage Frais',
#   'id': '1000377031656',
#   'promoId': 'ls92759',
#   'isFavourite': 'false',
#   'hasAlternates': 'false',
#   'wasPrice': '',
#   'brandName': 'Muller',
#   'promoType': 'No Promo',
#   'weight': '124g      ',
#   'promoOfferTypeCode': '15',
#   'promoQty': '10',
#   'promoValue': '£4',
#   'productAttribute': '',
#   'scene7AssetId': '4025500277031',
#   'promoDetail': '10 for £4',
#   'bundleDiscount': '0.00',
#   'avgStarRating': '4.7222',
#   'name': 'Muller Corner Vanilla Yogurt with Chocolate Balls',
#   'avgWeight': '',
#   'iconDetails': {},
#   'maxQty': '10.0',
#   'pricePerWt': 'Each',
#   'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000377031656',
#   'pricePerUOM': '',
#   'searchTuningScore': '4390417.0',
#   'onSale': False,
#   'salePrice': '',
#   'positionChngByMargin': 0},
#  {'shelfId': '1215286383583',
#   'shelfName': 'Corners',
#   'deptId': '1215341888021',
#   'deptName': 'Yogurts & Desserts',
#   'isBundle': 'false',
#   'meatStickerDetails': '10::for::£4::false',
#   'extraLargeImageURL': '',
#   'bundledItemCount': '0',
#   'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#   'cin': '7368408',
#   'promoDetailFull': '10 for £4',
#   'availability': 'A',
#   'totalReviewCount': '18',
#   'asdaSuggest': '',
#   'itemName': 'Corner Strawberry Yogurt',
#   'price': '£0.70',
#   'imageURL': '',
#   'aisleName': 'Yogurts & Fromage Frais',
#   'id': '1000377031677',
#   'promoId': 'ls92759',
#   'isFavourite': 'false',
#   'hasAlternates': 'false',
#   'wasPrice': '',
#   'brandName': 'Muller',
#   'promoType': 'No Promo',
#   'weight': '136g      ',
#   'promoOfferTypeCode': '15',
#   'promoQty': '10',
#   'promoValue': '£4',
#   'productAttribute': '',
#   'scene7AssetId': '4025500277239',
#   'promoDetail': '10 for £4',
#   'bundleDiscount': '0.00',
#   'avgStarRating': '4.6111',
#   'name': 'Muller Corner Strawberry Yogurt',
#   'avgWeight': '',
#   'iconDetails': {},
#   'maxQty': '10.0',
#   'pricePerWt': 'Each',
#   'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000377031677',
#   'pricePerUOM': '',
#   'searchTuningScore': '4268856.5',
#   'onSale': False,
#   'salePrice': '',
#   'positionChngByMargin': 0}]
# test loaded data
# 60
# {'shelfId': '1215286383583',
#  'shelfName': 'Corners',
#  'deptId': '1215341888021',
#  'deptName': 'Yogurts & Desserts',
#  'isBundle': 'false',
#  'meatStickerDetails': '10::for::£4::false',
#  'extraLargeImageURL': '',
#  'bundledItemCount': '0',
#  'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#  'cin': '7368400',
#  'promoDetailFull': '10 for £4',
#  'availability': 'A',
#  'totalReviewCount': '18',
#  'asdaSuggest': '',
#  'itemName': 'Corner Vanilla Yogurt with Chocolate Balls',
#  'price': '£0.70',
#  'imageURL': '',
#  'aisleName': 'Yogurts & Fromage Frais',
#  'id': '1000377031656',
#  'promoId': 'ls92759',
#  'isFavourite': 'false',
#  'hasAlternates': 'false',
#  'wasPrice': '',
#  'brandName': 'Muller',
#  'promoType': 'No Promo',
#  'weight': '124g      ',
#  'promoOfferTypeCode': '15',
#  'promoQty': '10',
#  'promoValue': '£4',
#  'productAttribute': '',
#  'scene7AssetId': '4025500277031',
#  'promoDetail': '10 for £4',
#  'bundleDiscount': '0.00',
#  'avgStarRating': '4.7222',
#  'name': 'Muller Corner Vanilla Yogurt with Chocolate Balls',
#  'avgWeight': '',
#  'iconDetails': {},
#  'maxQty': '10.0',
#  'pricePerWt': 'Each',
#  'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000377031656',
#  'pricePerUOM': '',
#  'searchTuningScore': '4390417.0',
#  'onSale': False,
#  'salePrice': '',
#  'positionChngByMargin': 0}

# %% [markdown]
# ## 4. Get Tweets
#
# Reference:
# - https://github.com/scalto/snscrape-by-location/blob/main/snscrape_by_location_tutorial.ipynb
# - https://medium.com/swlh/how-to-scrape-tweets-by-location-in-python-using-snscrape-8c870fa6ec25
#
# Note: User object is not exposed by TwitterSearchScraper any more.

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
#  search by keywords + time
# TwitterSearchScraper returns an interator, islice loops through the iterator

df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    '"blockchain + since:2021-12-1 until:2022-1-31"').get_items(), 500))

print(len(df))
df.head()
# Out:
# 500
#                                                  url  \
# 0  https://twitter.com/CryptoAnomalous/status/148...
# 1  https://twitter.com/gerard_dache/status/148793...
# 2  https://twitter.com/TrustCheckxyz/status/16212...
# 3  https://twitter.com/Rekttrading8/status/148793...
# 4  https://twitter.com/KeanuBelieves/status/14879...
#
#                        date  \
# 0 2022-01-30 23:59:59+00:00
# 1 2022-01-30 23:59:55+00:00
# 2 2023-02-02 23:27:56+00:00
# 3 2022-01-30 23:59:54+00:00
# 4 2022-01-30 23:59:50+00:00
#
#                                              content                   id  \
# 0  @BradSherman do not get in the way of US techn...  1487938677535907845
# 1  Congrats to Bill Rockwood Jr, Esq., MBA, J.D.,...  1487938658023919619
# 2  TrustCheck is your partner in crypto protectio...  1621289346040205312
# 3  @kararesurrect You are still announcing it on ...  1487938655159140353
# 4  @WatcherGuru @AffinityBSC. Being listing on a ...  1487938639820693508
#
#           username                                           outlinks  \
# 0  CryptoAnomalous                                                 []
# 1     gerard_dache  [https://lnkd.in/dqGwujW6, https://lnkd.in/dRn...
# 2    TrustCheckxyz                                                 []
# 3     Rekttrading8                                                 []
# 4    KeanuBelieves                                                 []
#
#                                           outlinksss  \
# 0
# 1  https://lnkd.in/dqGwujW6 https://lnkd.in/dRnUC_Yw
# 2
# 3
# 4
#
#                                          tcooutlinks  \
# 0                                                 []
# 1  [https://t.co/jhxRK9jjly, https://t.co/AsO08Xc...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                      tcooutlinksss
# 0
# 1  https://t.co/jhxRK9jjly https://t.co/AsO08XcIEm
# 2
# 3
# 4

# %%
df.content[0:20]
# Out:
# 0     @BradSherman do not get in the way of US techn...
# 1     Congrats to Bill Rockwood Jr, Esq., MBA, J.D.,...
# 2     TrustCheck is your partner in crypto protectio...
# 3     @kararesurrect You are still announcing it on ...
# 4     @WatcherGuru @AffinityBSC. Being listing on a ...
# 5                            @mine_blockchain scam mnet
# 6     46150 Well, who would have thought that? Minin...
# 7     The Stellar network enables change. Change in ...
# 8     👋 Hey! Wait! help me, help you, help us? Who's...
# 9     🐳 #Cardano $ADA Whale ❤️laced!\n💰 Transaction ...
# 10    TrustCheck is your partner in crypto protectio...
# 11    @TheVunderkind I still think we are yet to app...
# 12    63208 Well, who would have thought that? Minin...
# 13    @NathanielBandy1 Nintendo has a hard time putt...
# 14    39313 Well, who would have thought that? Minin...
# 15    The Stellar network enables change. Change in ...
# 16    Asian Company Uses Blockchain Technology to Pr...
# 17                         blockchain the piece of wood
# 18    📢 Crypto Market Status 📢  \n\n$GALA is trading...
# 19    Requesting $FTM funds from the #Stakely Faucet...
# Name: content, dtype: object

# %%
# search by user

df = pd.DataFrame(itertools.islice(sntwitter.TwitterUserScraper(
    '"zawphyowai199"').get_items(), 500))

print(len(df))
df.tail()
# Out:
# 500
#                                                    url  \
# 495  https://twitter.com/zawphyowai199/status/13652...
# 496  https://twitter.com/zawphyowai199/status/13648...
# 497  https://twitter.com/zawphyowai199/status/13644...
# 498  https://twitter.com/zawphyowai199/status/13644...
# 499  https://twitter.com/zawphyowai199/status/13642...
#
#                          date  \
# 495 2021-02-26 11:48:41+00:00
# 496 2021-02-25 11:13:11+00:00
# 497 2021-02-24 04:20:54+00:00
# 498 2021-02-24 04:17:08+00:00
# 499 2021-02-23 17:44:14+00:00
#
#                                                content                   id  \
# 495  @cryptomasters07 @FredrickNwa @eth_rift @LiveN...  1365267538259623937
# 496  @MidasDollar @BinanceChain @cz_binance @BearnF...  1364896218338390020
# 497    @1MillionTokens @mma728122 \n@mst5792 \n@wt7276  1364430076763246592
# 498  @phoswapofficial $PHO #BinanceSmartChain👍 \n#Y...  1364429127122493441
# 499  @bakery_swap @ape_swap #BananaBake\n#Bake\n#Nf...  1364269854350446592
#
#           username outlinks outlinksss tcooutlinks tcooutlinksss
# 495  zawphyowai199       []                     []
# 496  zawphyowai199       []                     []
# 497  zawphyowai199       []                     []
# 498  zawphyowai199       []                     []
# 499  zawphyowai199       []                     []

# %% [markdown]
# ## 5. Tweepy
# - Tweepy is a python library to access Twitter API.
# - `pip install tweepy`
# - The Tweepy documentation has detailed explanations: https://docs.tweepy.org/en/stable/
# - You need to apply for a developer account from here: https://developer.twitter.com/en/apply-for-access

# %%
import tweepy
import csv
import datetime

# https://docs.tweepy.org/en/stable/auth_tutorial.html

CONSUMER_KEY=''
CONSUMER_SECRET=''
ACCESS_KEY=''
ACCESS_SECRET=''

auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
api=tweepy.API(auth)

# %%
# Take a look at the public tweets from your account's home timeline 

public_tweets = api.home_timeline()
print(len(public_tweets))
for tweet in public_tweets[:2]:
    print(tweet.text)
# Out:
# 20
# Public Storage makes $11 billion hostile bid for Life Storage https://t.co/CIgJuBnSTy https://t.co/vZOg6ojHdr
# Firefighters battled dozens of raging wildfires in Chile, seeking to gain control of one of the country's worst nat… https://t.co/fACQjuZSzz

# %%
# is this useful information?
# Let's take a close look at ONE tweet json

public_tweets[0]
# there's no way to figure this out
# Out:
# Status(_api=<tweepy.api.API object at 0x7fdeb726cd90>, _json={'created_at': 'Mon Feb 06 02:35:17 +0000 2023', 'id': 1622423655387959303, 'id_str': '1622423655387959303', 'text': 'Public Storage makes $11 billion hostile bid for Life Storage https://t.co/CIgJuBnSTy https://t.co/vZOg6ojHdr', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/CIgJuBnSTy', 'expanded_url': 'http://reut.rs/3Yosrcp', 'display_url': 'reut.rs/3Yosrcp', 'indices': [62, 85]}], 'media': [{'id': 1622423653555097601, 'id_str': '1622423653555097601', 'indices': [86, 109], 'media_url': 'http://pbs.twimg.com/media/FoQBt4lX0AEbRGs.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FoQBt4lX0AEbRGs.jpg', 'url': 'https://t.co/vZOg6ojHdr', 'display_url': 'pic.twitter.com/vZOg6ojHdr', 'expanded_url': 'https://twitter.com/Reuters/status/1622423655387959303/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1200, 'h': 628, 'resize': 'fit'}, 'small': {'w': 680, 'h': 356, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 628, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1622423653555097601, 'id_str': '1622423653555097601', 'indices': [86, 109], 'media_url': 'http://pbs.twimg.com/media/FoQBt4lX0AEbRGs.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FoQBt4lX0AEbRGs.jpg', 'url': 'https://t.co/vZOg6ojHdr', 'display_url': 'pic.twitter.com/vZOg6ojHdr', 'expanded_url': 'https://twitter.com/Reuters/status/1622423655387959303/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1200, 'h': 628, 'resize': 'fit'}, 'small': {'w': 680, 'h': 356, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 628, 'resize': 'fit'}}}]}, 'source': '<a href="https://trueanthem.com/" rel="nofollow">True Anthem</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1652541, 'id_str': '1652541', 'name': 'Reuters', 'screen_name': 'Reuters', 'location': 'Around the world', 'description': 'Top and breaking news, pictures and videos from Reuters. For more breaking business news, follow @ReutersBiz.', 'url': 'http://t.co/BmHxhkm3Mh', 'entities': {'url': {'urls': [{'url': 'http://t.co/BmHxhkm3Mh', 'expanded_url': 'http://www.reuters.com', 'display_url': 'reuters.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 25732382, 'friends_count': 1234, 'listed_count': 136536, 'created_at': 'Tue Mar 20 17:46:05 +0000 2007', 'favourites_count': 743, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 970281, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '444444', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1194751949821939712/3VBu4_Sa_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1194751949821939712/3VBu4_Sa_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1652541/1573687397', 'profile_link_color': '006F97', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'F5F5F5', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 3, 'favorited': False, 'retweeted': False, 'possibly_sensitive': Fal ...

# %%
# make it look better
# convert to string
json_str = json.dumps(public_tweets[0]._json)

# deserialise string into python object
parsed = json.loads(json_str)


print(json.dumps(parsed, indent=4, sort_keys=True))
# Now we can have a better idea of the clustered relations of the json object
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Mon Feb 06 02:35:17 +0000 2023",
#     "entities": {
#         "hashtags": [],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/vZOg6ojHdr",
#                 "expanded_url": "https://twitter.com/Reuters/status/1622423655387959303/photo/1",
#                 "id": 1622423653555097601,
#                 "id_str": "1622423653555097601",
#                 "indices": [
#                     86,
#                     109
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/FoQBt4lX0AEbRGs.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/FoQBt4lX0AEbRGs.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 628,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "medium": {
#                         "h": 628,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "small": {
#                         "h": 356,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/vZOg6ojHdr"
#             }
#         ],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "reut.rs/3Yosrcp",
#                 "expanded_url": "http://reut.rs/3Yosrcp",
#                 "indices": [
#                     62,
#                     85
#                 ],
#                 "url": "https://t.co/CIgJuBnSTy"
#             }
#         ],
#         "user_mentions": []
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/vZOg6ojHdr",
#                 "expanded_url": "https://twitter.com/Reuters/status/1622423655387959303/photo/1",
#                 "id": 1622423653555097601,
#                 "id_str": "1622423653555097601",
#                 "indices": [
#                     86,
#                     109
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/FoQBt4lX0AEbRGs.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/FoQBt4lX0AEbRGs.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 628,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "medium": {
#                         "h": 628,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "small": {
#                         "h": 356,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/vZOg6ojHdr"
#             }
#         ]
#     },
#     "favorite_count": 3,
#     "favorited": false,
#     "geo": null,
#     "id": 1622423655387959303,
#     "id_str": "1622423655387959303",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://trueanthem.com/\" rel=\"nofollow\">True Anthem</a>",
#     "text": "Public Storage makes $11 billion hostile bid for Life Storage https://t.co/CIgJuBnSTy https://t.co/vZOg6ojHdr",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Tue Mar 20 17:46:05 +0000 2007",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Top and breaking news, pictures and videos from Reuters. For more breaking business news, follow @ReutersBiz.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "reuters.com",
#                         "expanded_url": "http://www.reuters.com",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/BmHxhkm3Mh"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 743,
#         "follow_request_sent": false,
#         "followers_count": 25732382,
#         "following": true,
#         "friends_count": 1234,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 1652541,
#         "id_str": "1652541",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 136536,
#         "location": "Around the world",
#         "name": "Reuters",
#         "notifications": false,
#         "profile_background_color": "444444",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1652541/1573687397",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1194751949821939712/3VBu4_Sa_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1194751949821939712/3VBu4_Sa_normal.jpg",
#         "profile_link_color": "006F97",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "F5F5F5",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "Reuters",
#         "statuses_count": 970281,
#         "time_zone": null,
#         "translator_type": "regular",
#         "url": "http://t.co/BmHxhkm3Mh",
#         "utc_offset": null,
#         "verified": true,
#         "withheld_in_countries": []
#     }
# }

# %% [markdown]
# ### 5.1. Get tweets from users' timeline
# - Make a Timeline call to retrieve the most recent 3200 tweets by a user (a rule set by Twitter).
#     - Note: the time range you get depends on how often the user posts tweets.
# - Parameters for the timeline call
#     - `count`: the number of results to try and retrieve per page. Maximum is 200.
#     - Make multiple calls to retrieve the 3200 tweets.
#     - `tweet_mode`:swaps the text index for full_text, and prevents a primary tweet longer than 140 characters from being truncated.
# - Variables of tweet objects
#     - https://docs.tweepy.org/en/stable/api.html#tweepy-api-twitter-api-wrapper

# %%
# Get the first five tweets of a user.
timeline = api.user_timeline(screen_name="KelloggCompany",count=5,tweet_mode="extended")

for status in timeline:
    print (status.id)
    print (status.full_text)
# Out:
# 1586056988315844610
# We're proud to be ranked #2 in the @Access to Nutrition Initiative 2022 US Access to Nutrition Index. We remain committed to providing access to nutritious foods to create #betterdays for people in the U.S. and across the world. #LifeAtK #ESG #ATNIUSIndex https://t.co/AMHkEMwiO8 https://t.co/0vrgkkkojK
# 1585399725930729472
# One easy way to help kids get excited about going to school? Serve school breakfast!
#
# According to new research, children who attend breakfast programs are excited about going to school.
#
# Learn about this and other social benefits: https://t.co/9Dx1ggxfDA https://t.co/qSWUGGd8eC
# 1585240451036381184
# RT @KelloggCompany: Webcast alert! Kellogg &amp; @foodbanking will host a discussion about new research on the benefits of school breakfast pro…
# 1584897978136944641
# Webcast alert! Kellogg &amp; @foodbanking will host a discussion about new research on the benefits of school breakfast programs &amp; the role that food banks play in supporting these programs. Live on Oct. 26 at 9 a.m. ET. #BetterDays .  Register here: https://t.co/Q8AQsvoFRC https://t.co/ZtnwYie4XP
# 1583159737117724673
# RT @frootloops: Pick-up your limited-edition Rise &amp; Kind box of Froot Loops and show your support by wearing purple for #SpiritDay.  This c…

# %%
# Step 1: get a list of tweets 
# Step 2: extract the varaibles you want

def get_all_tweets(user_name):
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
    api=tweepy.API(auth)
    
    # initialize the first call
    alltweets=[]
    new_tweets=api.user_timeline(screen_name=user_name, count=200)
    alltweets.extend(new_tweets)
    oldest=alltweets[-1].id-1  #next time start from the oldest one minus one 
    
    # continue to get tweets
    while len(new_tweets)>0:  
        print ("getting tweets before", oldest)
        new_tweets = api.user_timeline(screen_name=user_name,count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest=alltweets[-1].id-1
        print("...{} tweets downloaded so far".format(len(alltweets)))
    
    # extract the variables you want
    outtweets = [[tweet.id_str, tweet.user.name, tweet.created_at, tweet.user.followers_count,
                  tweet.text.encode("utf-8")] for tweet in alltweets]
            
    # write out your variables
    with open('%s_tweet.csv' % user_name,'w') as outputfile: 
        writer=csv.writer(outputfile)
        writer.writerow(["id","user_name","created_at","followers","text"])
        writer.writerows(outtweets)
    pass

# use your function
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("KelloggCompany")
# Out:
# getting tweets before 1436313521776701471
# ...400 tweets downloaded so far
# getting tweets before 1372185589525717001
# ...600 tweets downloaded so far
# getting tweets before 1310917338070429695
# ...800 tweets downloaded so far
# getting tweets before 1235602518031372287
# ...1000 tweets downloaded so far
# getting tweets before 1171171132633997314
# ...1200 tweets downloaded so far
# getting tweets before 1097565742130712576
# ...1400 tweets downloaded so far
# getting tweets before 1007004846355083263
# ...1599 tweets downloaded so far
# getting tweets before 930802267111882751
# ...1799 tweets downloaded so far
# getting tweets before 871796275842138111
# ...1999 tweets downloaded so far
# getting tweets before 798912118175080448
# ...2199 tweets downloaded so far
# getting tweets before 751417169762717696
# ...2396 tweets downloaded so far
# getting tweets before 704673280029020160
# ...2594 tweets downloaded so far
# getting tweets before 656850808840003583
# ...2793 tweets downloaded so far
# getting tweets before 592687275378630657
# ...2992 tweets downloaded so far
# getting tweets before 525285833352679423
# ...3186 tweets downloaded so far
# getting tweets before 449231226067750911
# ...3186 tweets downloaded so far

# %%
# Take a look at the table you got
df= pd.read_csv('KelloggCompany_tweet.csv', header=0)
df.head()

# how many tweets we get?
len(df)

# The following tweet is a retweet. Take a look at the text.
# The index of this retweet is based on the table generated previously
# if you run at a different time, you will see a differet tweet
# try to find a retweet and compare the text with the actual tweet
# You can find each tweet on Twitter by its ID.
df.text[0]
# Out:
#                     id        user_name           created_at  followers  \
# 0  1586056988315844610  Kellogg Company  2022-10-28 18:07:08      77052
# 1  1585399725930729472  Kellogg Company  2022-10-26 22:35:24      77052
# 2  1585240451036381184  Kellogg Company  2022-10-26 12:02:30      77052
# 3  1584897978136944641  Kellogg Company  2022-10-25 13:21:38      77052
# 4  1583159737117724673  Kellogg Company  2022-10-20 18:14:29      77052
#
#                                                 text
# 0  b"We're proud to be ranked #2 in the @Access t...
# 1  b'One easy way to help kids get excited about ...
# 2  b'RT @KelloggCompany: Webcast alert! Kellogg &...
# 3  b'Webcast alert! Kellogg &amp; @foodbanking wi...
# 4  b'RT @frootloops: Pick-up your limited-edition...
# 3186
# 'b"We\'re proud to be ranked #2 in the @Access to Nutrition Initiative 2022 US Access to Nutrition Index. We remain com\\xe2\\x80\\xa6 https://t.co/Xo15b3andL"'

# %% [markdown]
# ### 5.2. Deal with truncated text
# - For text mining on Twitter, it is important to get the full text.
#     - Full text would be essential for topic modeling and sentiment analysis.
#     - Full text is also important for extracting mention networks (note the previous example).
# - Use the `tweet_mode="extended"` when calling a user's timeline.
#     - When using extended mode, the `text` attribute of Status objects returned is replaced by a `full_text` attribute, which contains the entire untruncated text of the Tweet.
# - Full text for tweets that are retweets.
#     - If the tweet is a retweet, the full_text is still truncated.
#     - We need to access the full text through `retweeted_status` attribute, which is a status object itself.
# - For reference: https://docs.tweepy.org/en/stable/extended_tweets.html

# %%
# Let's deal with retweets

def get_all_tweets(user_name):
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
    api=tweepy.API(auth,wait_on_rate_limit=True)

    alltweets=[]
    new_tweets=api.user_timeline(user_name, count=200,tweet_mode="extended")
    alltweets.extend(new_tweets)
    oldest=alltweets[-1].id-1  
    
    # set date condition
    startDate=datetime.datetime(2022, 10, 1, 0, 0, 0)
    while new_tweets[-1].created_at > startDate:
        print ("getting tweets before", oldest)
        new_tweets = api.user_timeline(user_name,count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest=alltweets[-1].id-1
        print("...{} tweets downloaded so far".format(len(alltweets)))
        
    # check if it's a retweet
    # When using extended mode with a Retweet, the full_text attribute of the Status object may be truncated    
    # However, since the retweeted_status attribute (of a Status object that is a Retweet) is itself a Status object
    # the full_text attribute of the Retweeted Status object can be used instead.
    
    outtweets_all=[]
    for tweet in alltweets:
        status = api.get_status(tweet.id, tweet_mode="extended")
        
        if hasattr(status, "retweeted_status"):  # is a retweet
            full_text=status.retweeted_status.full_text.encode("utf-8")
            
            outtweets=[
            # tweet content
            tweet.id_str, tweet.created_at,full_text,
            # user features
            tweet.user.name, tweet.user.screen_name, tweet.user.followers_count, 
            # retweet features
            tweet.retweeted_status.user.name,tweet.retweeted_status.user.screen_name,tweet.retweeted_status.user.description]
            outtweets_all.append(outtweets)
  
        else: # not a retweet
            full_text=status.full_text.encode("utf-8")
                    
            outtweets=[
            # tweet content
            tweet.id_str, tweet.created_at,full_text,
            # user features
            tweet.user.name, tweet.user.screen_name, tweet.user.followers_count, 
            # retweet features
            "no value","no value","no value"]
            outtweets_all.append(outtweets)

    with open('%s_full_tweet.csv' % user_name,'w') as outputfile: 
        writer=csv.writer(outputfile)
        writer.writerow(["id","created_at","full_text",
                        "user.name","user.screen_name","user.followers_count",
                        "retweeted_status.user.name","retweeted_status.user.screen_name","retweeted_status.user.description"])
        writer.writerows(outtweets_all)

        
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("KelloggCompany")
# Out:
# getting tweets before 1436313521776701471
# ...400 tweets downloaded so far
# getting tweets before 1372185589525717001
# ...600 tweets downloaded so far

# %%
df= pd.read_csv('KelloggCompany_full_tweet.csv', header=0)
df.head()
len(df)
# plese compare this full text with the above truncated text, what differences can you find?
df.full_text[0]
# Out:
#                     id           created_at  \
# 0  1586056988315844610  2022-10-28 18:07:08
# 1  1585399725930729472  2022-10-26 22:35:24
# 2  1585240451036381184  2022-10-26 12:02:30
# 3  1584897978136944641  2022-10-25 13:21:38
# 4  1583159737117724673  2022-10-20 18:14:29
#
#                                            full_text        user.name  \
# 0  b"We're proud to be ranked #2 in the @Access t...  Kellogg Company
# 1  b'One easy way to help kids get excited about ...  Kellogg Company
# 2  b'Webcast alert! Kellogg &amp; @foodbanking wi...  Kellogg Company
# 3  b'Webcast alert! Kellogg &amp; @foodbanking wi...  Kellogg Company
# 4  b'Pick-up your limited-edition Rise &amp; Kind...  Kellogg Company
#
#   user.screen_name  user.followers_count retweeted_status.user.name  \
# 0   KelloggCompany                 77052                   no value
# 1   KelloggCompany                 77052                   no value
# 2   KelloggCompany                 77052            Kellogg Company
# 3   KelloggCompany                 77052                   no value
# 4   KelloggCompany                 77052                Froot Loops
#
#   retweeted_status.user.screen_name         retweeted_status.user.description
# 0                          no value                                  no value
# 1                          no value                                  no value
# 2                    KelloggCompany                   https://t.co/ejl5pSUP0e
# 3                          no value                                  no value
# 4                        frootloops  It’s spelled Froot. Play now on Roblox 🎮
# 600
# 'b"We\'re proud to be ranked #2 in the @Access to Nutrition Initiative 2022 US Access to Nutrition Index. We remain committed to providing access to nutritious foods to create #betterdays for people in the U.S. and across the world. #LifeAtK #ESG #ATNIUSIndex https://t.co/AMHkEMwiO8 https://t.co/0vrgkkkojK"'

# %% [markdown]
# ### 5.3. Build Twitter networks
# - **Follower-followee network**
#     - If you have a list of user accounts, you may retrive the pairwise boolean values of following relations.
#     - Parameters
#         * `source_id` – The user_id of the subject user.
#         * `source_screen_name` – The screen_name of the subject user.
#         * `target_id` – The user_id of the target user.
#         * `target_screen_name` – The screen_name of the target user.
# - **Retweet network**
#     - Retweeted accounts can be extracted while scraping the API.
#     - Or retweeted accounts can be extracted from the text.
# - **Mention network**
#     - Can be extracted from the full text.

# %%
# How to scrape the follower-followee network?
# we can directly retrieve a bollean value 

dog="Microsoft"
cat="Oracle"

is_following = api.show_friendship(source_screen_name=cat,target_screen_name=dog)
print(is_following[1].following)

# Question: how to get the adjacency matrix of a follower-followee network?
# Out:
# False

# %% [markdown]
# ### 5.4 Keywords search

# %%
# Define the search term and the date_since date as variables
search_words = "blockchain"
date_since = "2021-11-01"
#removed

# Collect tweets
tweets = tweepy.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(5)


# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @chiqshoes: Make this egg the most liked post on Twitter🔥
#
# @MandoxCreate @Wire_Blockchain #Egg #NFT #NFTs https://t.co/yLllS767Zh
# RT @lovetr33_xyz: LoveTr33 is an experimental project designed to allow people to express and celebrate love on Valentine's day in a web3 a…
# RT @ReautyDao: #Reautydao #Fridaybrews: Beauty brands are taking their operations to the next level with web3,blockchain &amp; AI!From improved…
# RT @Ronald_vanLoon: What Is Contract Intelligence?
# by @monishdarda @Forbes
#
# Read more: https://t.co/nafLmwTZ0m
#
# #AI #BigData #ArtificialInt…
# RT @EOSnFoundation: The #EOS EVM is a major catalyst for the $EOS blockchain on the path to mass adoption 🔥
#
# This recent feature with @cryp…

# %% [markdown]
# ##### Twitter data resources
# https://github.com/echen102/us-pres-elections-2020 <br>
# https://github.com/echen102/COVID-19-TweetIDs
