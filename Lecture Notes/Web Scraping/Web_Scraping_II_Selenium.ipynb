# %% [markdown]
# # <center>Web Scraping II -- Dyamic Web Page Scraping with Selenium </center>
#
# References:
# - http://selenium-python.readthedocs.io/getting-started.html
# - https://www.scrapingbee.com/blog/selenium-python/
# - https://www.selenium.dev/documentation/webdriver/

# %% [markdown]
# ## 1. Why Selenium
# - When **Requests + BeautifulSoup** don't work?
#   - Elements in a web page loaded **asynchronously**
#      * while requests.get(url) can only return the initial content
#      * you may need to wait for a while to get web content fully loaded
#   - You need to **interact with the page** to get some content loaded, e.g.
#      * scroll down to load more
#      * click a button like "more"
#      * close a pop-up ad window
#      * fill a form
# - Example: https://www.quora.com/topic/Machine-Learning

# %%
# Exercise 1.1. Scape quora page using requests+beautifulsoup

# import requests package
import requests    
import time

# import BeautifulSoup from package bs4 (i.e. beautifulsoup4)
from bs4 import BeautifulSoup   

page = requests.get("https://www.quora.com/topic/Machine-Learning")    # send a get request to the web page


if page.status_code==200:      

    soup = BeautifulSoup(page.content, 'html.parser')
    print(soup.prettify())

    
    # get all questions
    questions=soup.select("span.q-box.qu-userSelect--text")
    
    for i, q in enumerate(questions):
        print(i, q.get_text())
        #print("\n")

# Note: nothing is returned. Do you know why?
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" style="padding: 0; margin: 0;">
#  <head prefix="og: http://ogp.me/ns#">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link as="script" href="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-27-8966a075a796ee0b.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-vendor-27-124786ae6e218fb7.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-a77e033cc70881b2.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-page-TopicPageLoadable-27-0ac2c55ce7a74149.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Multifeed-27-16cc54d33114b770.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-TopicTab-ReadWrite-27-82707ab906e6e230.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-9f7886c37cb85093.webpack" rel="preload"/>
#   <link as="style" href="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-main.css-28-44eca84cb77e455e.webpack" rel="preload"/>
#   <link href="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-main.css-28-44eca84cb77e455e.webpack" id="ans-frontend-main-css" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    function reportToAndroid(){if(0!==assetErrs.length){var e=window.QuoraAndroid;e&&e.reportBrowserAssetLoadErrors&&e.reportBrowserAssetLoadErrors(assetErrs)}}var assetErrs=[];document.addEventListener("DOMContentLoaded",function(e){setTimeout(function(){if(0!==assetErrs.length){var e="assets="+encodeURIComponent(JSON.stringify(assetErrs)),r=new XMLHttpRequest;r.open("POST","/ajax/log_browser_asset_load_error_3RD_PARTY_POST",!0),r.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),r.setRequestHeader("Accept","*/*"),r.send(e.replace(/%20/g,"+"))}},0),setTimeout(function(){reportToAndroid()},500)}),window.addAssetErr=function(e){e&&assetErrs.push(e)};
#   </script>
#   <script id="entryjs_wrapper" type="text/javascript">
#    window.__entryChunkLoaded = false;
#         window.__onEntryLoaded = [];
#         window.executeAfterEntryjsLoaded = function (callback) {
#             if (window.__entryChunkLoaded) {
#                 callback();
#             } else {
#                 window.__onEntryLoaded.push(callback);
#             }
#         }
#   </script>
#   <script type="text/javascript">
#    window.isReactPage = true;window.isReactLoaded = true;window.ansFrontendRelayWebpackManifest = {"common":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-a77e033cc70881b2.webpack","common-LoggedOut":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-9f7886c37cb85093.webpack","common-Mweb":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-common-Mweb-27-bd2529e3a67bafb1.webpack","common-NativeApp":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-common-NativeApp-27-4d1cc1e66d5de794.webpack","common-secondary":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-common-secondary-27-a390d28eaada01fd.webpack","component-ActivationDeckInner":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-ActivationDeckInner-27-730af978be940956.webpack","component-AdCTABanner":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-AdCTABanner-27-10e7d1db78291fe8.webpack","component-AdminTools-profile":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-AdminTools-profile-27-734fb2afadc6946f.webpack","component-AnnouncementBundle":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnnouncementBundle-27-2b15b304f9d1d8ff.webpack","component-AnswerFooter":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnswerFooter-27-3384c8a1c34cf7fa.webpack","component-AnswerPageFooter":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnswerPageFooter-27-a3633591ee1aea0c.webpack","component-CaptchaPopper":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-CaptchaPopper-27-defbf5aa7e4c6cf4.webpack","component-CollapseAnswerSection":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-CollapseAnswerSection-27-1e5c7860cb5a49a5.webpack","component-Comments":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Comments-27-3031cbd43a6eb354.webpack","component-Composer":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Composer-27-3d2a98e8abc708b4.webpack","component-DesktopMessagesDock":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-DesktopMessagesDock-27-04bf507f0f3fa311.webpack","component-FeedSwitcher":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-FeedSwitcher-27-b6348e4c1f119b4a.webpack","component-FirstFeedScrollPrompt":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-FirstFeedScrollPrompt-27-7c033109065caa33.webpack","component-FollowTribeSuggestionsList":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-FollowTribeSuggestionsList-27-ade6fd9546800caf.webpack","component-Hovercards":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Hovercards-27-ca2df8c007c373a0.webpack","component-ImageViewer":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-ImageViewer-27-99ff9f9e96a84591.webpack","component-LexicalEditor":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-LexicalEditor-27-64a89aec9fc6c48c.webpack","component-LoggedOutFeed":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-LoggedOutFeed-27-f31f207a3c91f459.webpack","component-Login":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Login-27-9a3bf21180064101.webpack","component-MobileLookup":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-MobileLookup-27-d07a4804db312a34.webpack","component-Modals-AdsConsumer":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsConsumer-27-360c872b400de273.webpack","component-Modals-AdsManager":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsManager-27-383315589c57d2c6.webpack","component-Modals-AskQuestion":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AskQuestion-27-57b994488a24d9d4.webpack","component-Modals-Business":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-Business-27-1f6ca9e82169fdfa.webpack","component-Modals-EarningsPrograms":"https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-EarningsProgr ...
# var includedChunks = window.ansFrontendRelayWebpackIncludedChunks;
# window.ansFrontendRelayWebpackIncludedChunks = (includedChunks || []).concat(["vendor","common","page-TopicPageLoadable","component-Multifeed","component-TopicTab-ReadWrite","common-LoggedOut"]);
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.earlySettings = {"formkey": "c131fa94f54d73f29779b00f8e02b023", "errorSamplingRate": 1.0, "interfaceLanguageCode": "en", "isDevCode": false, "isMobileAppPrefetched": false, "topLevelNid": 0, "react_console_log_perf_info": false, "subdomainSuffix": "quora.com", "windowId": "react_jabzrwppznirkdfv", "rootClsKey": "TopicPage", "rootQueryVariables": {"tid": 948, "initialTab": "read"}, "rootProps": {"tid": 948, "initialTab": "read"}, "inlineQueryEnabled": true, "inlineQueryHashes": {"e84480196bc96c74a99c9a7e3c06c340e9b3e320cd8a773ba5a0d696ebf3f1f8": true, "2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e": true, "c818677a71ee52a948df8a8ec246653cb5ab305dca610cdc075e6c663ae32ef9": true}, "pageShellInfo": null, "shouldServerRender": false, "hasIndicator": true, "isServiceWorkerConstructed": false, "csrEnabled": false};
#   </script>
#   <script type="text/javascript">
#    function getLoggingUrl(){var e="/ajax/page_bounce_POST";return"quora.com"==window.ansFrontendGlobals.earlySettings.subdomainSuffix?"https://log.quora.com/ajax/page_bounce_POST":e}function logPageBounce(e){if(window.isReactPage&&!window.reportedPageLoadBounce&&!window.ansFrontendGlobals.earlySettings.isMobileAppPrefetched&&!window.ansFrontendGlobals.earlySettings.isPrefetchedPage){window.reportedPageLoadBounce=!0;var n=window.ansFrontendGlobals.earlySettings.windowId,o={url:window.location.href,windowId:n,wasViewed:window.wasViewed};if(window.performance&&window.performance.timing){var a=window.performance.timing.navigationStart;a&&(o.unloadTime=Date.now()-a,o.cause=e)}var i=getLoggingUrl(),t=window.ansFrontendGlobals.earlySettings.formkey,d=[{category:"unload_before_page_ready",data:o,time:1e3*Date.now()}];try{var r=new window.FormData;r.append("messages",JSON.stringify(d)),r.append("formkey",t),window.navigator.sendBeacon(i,r)}catch(w){var s=new XMLHttpRequest;s.open("POST",i,!0),s.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),
# s.setRequestHeader("Quora-Formkey",t);var g="messages="+encodeURIComponent(JSON.stringify(d));s.setRequestHeader("Accept","*/*"),s.send(g.replace(/%20/g,"+"))}}}window.wasViewed="visible"===document.visibilityState,window.addEventListener("beforeunload",function(e){logPageBounce("beforeunload")}),window.addEventListener("pagehide",function(e){logPageBounce("pagehide")}),window.addEventListener("visibilitychange",function(e){"hidden"===document.visibilityState?logPageBounce("visibilitychange_hidden"):window.wasViewed=!0});
#   </script>
#   <script async="1" id="entryjs" onerror="addAssetErr(this.src)" src="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-27-8966a075a796ee0b.webpack" type="text/javascript">
#   </script>
#   <script async="1" onerror="addAssetErr(this.src)" src="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-vendor-27-124786ae6e218fb7.webpack" type="text/javascript">
#   </script>
#   <script async="1" onerror="addAssetErr(this.src)" src="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-a77e033cc70881b2.webpack" type="text/javascript">
#   </script>
#   <script async="1" onerror="addAssetErr(this.src)" src="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-page-TopicPageLoadable-27-0ac2c55ce7a74149.webpack" type="text/javascript">
#   </script>
#   <script async="1" onerror="addAssetErr(this.src)" src="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-Multifeed-27-16cc54d33114b770.webpack" type="text/javascript">
#   </script>
#   <script async="1" onerror="addAssetErr(this.src)" src="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-component-TopicTab-ReadWrite-27-82707ab906e6e230.webpack" type="text/javascript">
#   </script>
#   <script async="1" onerror="addAssetErr(this.src)" src="https://qsc.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-9f7886c37cb85093.webpack" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    window.executeAfterEntryjsLoaded(() => window.runApp());
#   </script>
#   <title>
#    Machine Learning - Quora
#   </title>
#   <link href="https://qsf.cf2.quoracdn.net/-4-images.favicon-new.ico-26-07ecf7cd341b6919.ico" rel="icon"/>
#   <meta content="noindex, follow" name="robots"/>
#   <meta content="255232486973" property="fb:pages"/>
#   <meta content="light" name="twitter:widgets:theme"/>
#  </head>
#  <body class="q-platform--desktop" style="margin: 0;padding: 0;">
#   <div id="staticError" style="display: none;">
#    <div style='height: 100vh; display: flex; font-size: 15px;background-color: #fff; color: #282829;flex-direction: column; align-items: center; justify-content: center;font-family: -apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;'>
#     <svg height="24px" viewbox="0 0 24 24" width="24px">
#      <g fill="none" fillrule="evenodd" id="error" stroke="none" transform="translate(3.000000, 3.000000)">
#       <path classname="icon_svg-fill_as_stroke" d="M9,12 C9.55228475,12 10,12.4477153 10,13 C10,13.5522847 9.55228475,14 9,14 C8.44771525,14 8,13.5522847 8,13 C8,12.4477153 8.44771525,12 9,12 Z" fill="#666666" fillrule="nonzero">
#       </path>
#       <path classname="icon_svg-stroke" d="M9,9.5 L9,4.5 L9,9.5 Z M9,18 C4.029,18 0,13.971 0,9 C0,4.029 4.029,0 9,0 C13.971,0 18,4.029 18,9 C18,13.971 13.971,18 9,18 Z" stroke="#666" strokelinecap="round" strokewidth="1.5">
#       </path>
#      </g>
#     </svg>
#     <p style="text-align: center; margin-top: 8px; max-width: 60vw;margin-bottom: 16px;">
#      Something went wrong. Wait a moment and try again.
#     </p>
#     <button onclick="location.reload();" style='padding: 8px 16px;font-size: 15px; background-color: #2E69FF; color: #fff;border: 0; border-radius: 9999em; appearance: none;cursor:pointer;-webkit-appearance: none;font-family:-apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;'>
#      Try again
#     </button>
#    </div>
#   </div>
#   <script type="text/javascript">
#    window.addEventListener("load",function(e){window.errorTimer=window.setTimeout(function(){var e=document.getElementById("root");if(e&&e.children&&0===e.children.length&&!window.initialRenderComplete){var t=document.getElementById("loader");t&&t.remove();var n=document.getElementById("staticError");if(n&&n.style&&n.style.display){n.style.display="block";var o=new XMLHttpRequest;o.open("POST","/ajax/log_static_error_state_shown_3RD_PARTY_POST",!0),o.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),o.setRequestHeader("Accept","*/*"),o.send("")}}},1e4)});
#   </script>
#   <div class="" id="loader" style='height: calc(100vh - 50px);margin-top: 50px;display: flex;font-size: 15px;background-color: #fff;flex-direction: column;align-items: center;justify-content: center;font-family: -apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif'>
#    <div style="position: fixed;top: 0;left: 0;right: 0;height: 50px;background-color: #fff;border-bottom: 1px solid rgb(222, 224, 225);box-shadow: 0 3px 6px rgba(0, 0, 0, 0.04)">
#    </div>
#    <style>
#     @keyframes loader-line{0%{transform:translateX(calc(-100% + 3px));opacity:.5}25%,75%{opacity:1}50%{transform:translateX(calc(100% - 3px));opacity:.5}100%{transform:translateX(calc(-100% + 3px));opacity:.5}}@keyframes entrance{0%{transform:scale(.9);opacity:0}100%{transform:scale(1);opacity:1}}@keyframes logo-entrance{100%{fill:#b92b27;opacity:1}}@keyframes logo-entrance-dark{100%{fill:#f52936;opacity:1}}#loader svg{width:48px;height:48px}#loader svg path{fill:#8e9092;opacity:.6;animation:logo-entrance .15s ease-in forwards;animation-delay:1s}#loader.loader-dark svg path{fill:#8e9092;animation-name:logo-entrance-dark}
#    </style>
#    <svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path class="icon_svg-fill_as_stroke" d="M20.7364 19.4633L18.9688 17.6952C20.2382 16.1439 21.0001 14.161 21.0001 12C21 7.02939 16.9705 3 12 3C7.02939 3 3 7.02939 3 12C3 16.9705 7.02948 20.9999 12 21C12.0114 21 12.0226 20.9996 12.0339 20.9996H20.0999C20.9016 20.9996 21.3032 20.0303 20.7364 19.4633ZM6.59998 12C6.59998 9.01765 9.01765 6.59998 12 6.59998C14.9823 6.59998 17.3999 9.01765 17.4 12C17.4 14.9823 14.9823 17.3999 12 17.3999C9.01765 17.4 6.59998 14.9823 6.59998 12Z" fill="#B92B27">
#     </path>
#    </svg>
#    <div style="height: 3px;width: 20px;position: relative;border-radius: 1000px;margin-top: 6px;overflow: hidden;animation: entrance .15s ease-in 1s 1 both">
#     <div style="position: absolute;top: 0px;bottom: 0px;left: 0px;width: 100%;background-color: rgba(0, 0, 0, 0.2);border-radius: 1000px;animation: loader-line 1.5s cubic-bezier(0.83, 0, 0.17, 1) 1s infinite both;transform-origin: left center;opacity: 0">
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    window.loaderTimer=setTimeout(function(){var e=document.getElementById("loader");e&&e.style&&e.style.display&&(e.style.display="flex")},100);
#   </script>
#   <div id="root">
#   </div>
#   <noscript>
#    Please enable Javascript and refresh the page to continue
#   </noscript>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.settings = {"action": "t", "controller": "topic", "pageType": "topic", "pageOid": 948, "getPageTypeOfRefererUrl": null, "getParams": {}, "cookiePrefix": "m", "nid": 0, "revision": "4dfdd6b23754030a82a2e59cead169e0d1c0c989", "isCanaryRevision": false, "debugToolsEnabled": false, "graphqlClientRequestLogging": true, "persistedQueriesEnabled": true, "postkey": "7b40bf3e827c2cb1595d2a7f8d3178e4", "buildNumber": 0, "broadcastId": "main-w-chan50-8888-react_jabzrwppznirkdfv-zgP7", "broadcastDisabled": false, "tchannelData": null, "viewerUniversalUid": null, "viewerMemberUid": null, "isUniversalQuoraEmployee": false, "isMemberQuoraEmployee": false, "shouldReportE2E": true, "shouldReportReactLoadableE2E": true, "cdn": "cloudflare", "request_id": "0558475e8b0148789969a001d0239f4e", "actionTrail": null, "clientLogTrail": null, "experiments": {"test_experiment_name_2": null, "concurrent_react_logged_in": null, "concurrent_react_logged_out": null, "use_functional_answer_feed_story": null, "use_functional_answer_overflow_menu": null, "app_download_wall_holdout": null, "programmatic_ads_i18n_feed_holdout": null, "programmatic_ads_en_feed_holdout": null, "remove_more_stories_from_digest_ad": null, "promoted_answer_with_thumbnail_top_slot_question_logged_in": null, "promoted_answer_with_thumbnail_top_slot_question_logged_out": null, "ads_manager_funnel_account_creation_holdout": null, "ad_surveys_on_feed": null, "question_page_inline_image_ads_logged_in": null, "question_page_inline_image_ads_logged_out": null, "feed_promoted_answer_with_footer": null, "show_ads_on_stand_alone_answer_page": null, "show_ads_on_stand_alone_answer_page_logged_out": null, "subscriptions_logged_in_holdout": null, "subscriptions_quora_plus_corner_badge_2": null, "quora_plus_price_testing": null, "enable_answer_expand_ads_on_question_page": null, "enable_answer_expand_ads_on_question_page_logged_out": null, "gpt_feed_answer_expand_mobile_v3": null, "two_gpt_question_page_logged_in": null, "two_gpt_question_page_logged_out": null, "subscription_painted_door_test": null, "show_ad_upvote_number_logged_in": null, "show_ad_upvote_number_logged_out": null, "two_gpt_question_page_logged_in_en": null, "two_gpt_question_page_logged_out_en": null, "subscription_prominent_cancel_button": null, "gpt_feed_answer_expand_desktop_i18n": null, "li_ads_learning": null, "layout_shift_on_video_ads": null, "unified_checklist_deck": null, "relevant_answer_subfeed": null, "feedback_response_ui": null, "downvote_feedback_question_link": null, "native_feed_modal_replace_tribe_suggestions": null, "feed_adjust_margin_and_question_title": null, "comments_input_field": null, "bookmark_button_additional_locations": null, "raise_nav_bar_bookmarks_position": null, "continue_reading_last_story": null, "remove_feed_sidebar_space_suggestions": null, "prefetched_link_delay": null, "unify_share_button_desktop": null, "unify_share_button_mobile": null, "making_bundle_header_click_target": null, "feed_start_tti_inp": null, "two_column_desktop_homefeed": null, "new_button_system": null, "interleave_digest_and_feed2": null, "new_button_system_logged_out": "emphasize_primary_action", "action_bar_ui_redesign": null, "prefetched_link_delay_holdout": null, "suggested_tribe_email_notif_holdout": null, "mweb_new_navbar": null, "editor_unification_move_audience_picker_add_credential_picker": null, "react_qtext_embeds_preview_eager_loading_logged_in_v2": null, "offroad_mweb_nav": null, "add_badge_to_high_feed_survey_rating_answers": null, "giphy_button": null, "remove_user_input_topic": null, "show_signup_component_question_page": null, "pua_expand_injected_answer_post_signup": null, "question_page_no_partial_expand_logged_in": null, "question_page_no_partial_expand_logged_out": null, "logged_out_home_feed": null, "question_page_skip_next_answer": null, "question_page_skip_next_answer_logged_out": null, "question_page_signup_pr ...
#   </script>
#   <script type="text/javascript">
#    window.executeAfterEntryjsLoaded(() => window.installSettings());
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};window.ansFrontendGlobals.data.inlineQueryResults.results["2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e"] = window.ansFrontendGlobals.data.inlineQueryResults.results["2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e"] || [];window.ansFrontendGlobals.data.inlineQueryResults.results["2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e"].push("{\"data\":{\"viewer\":{\"id\":\"Vmlld2VyQDA6MA==\",\"__typename\":\"Viewer\",\"user\":null,\"uid\":null,\"nid\":0,\"silosBadgeCount\":\"{}\",\"memberNetworks\":[],\"showGoToFeedGrowl\":false,\"showGoToFeedGrowlBadge\":false,\"followingTabBadgeCount\":0,\"writeNavBadgeCount\":0,\"profileNavBadgeCount\":0,\"tribeNavBadgeCount\":0,\"inboxCount\":0,\"notificationNavBadgeCount\":0,\"consumerBundleSubscription\":null,\"isAdminMode\":false,\"canSeeAds\":true},\"viewInAppLink\":{\"id\":\"Vmlld0luQXBwTGlua0AwOjA=\"}},\"extensions\":{\"is_final\":false}}");window.ansFrontendGlobals.data.inlineQueryResults.next["2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e"] && window.ansFrontendGlobals.data.inlineQueryResults.next["2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e"]();
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};window.ansFrontendGlobals.data.inlineQueryResults.results["c818677a71ee52a948df8a8ec246653cb5ab305dca610cdc075e6c663ae32ef9"] = window.ansFrontendGlobals.data.inlineQueryResults.results["c818677a71ee52a948df8a8ec246653cb5ab305dca610cdc075e6c663ae32ef9"] || [];window.ansFrontendGlobals.data.inlineQueryResults.results["c818677a71ee52a948df8a8ec246653cb5ab305dca610cdc075e6c663ae32ef9"].push("{\"data\":{\"viewer\":{\"user\":null,\"bannerJoinPromptNetwork\":null,\"shouldShowNonMemberJoinNetworkModal\":false,\"googleOneTapEnabled\":true,\"network\":{\"canonicalSubdomain\":\"www\",\"id\":\"TmV0d29yazow\"},\"id\":\"Vmlld2VyQDA6MA==\",\"__typename\":\"Viewer\",\"isUniversalLoggedIn\":false,\"notificationNavBadgeCount\":0,\"inboxCount\":0},\"network\":{\"id\":\"TmV0d29yazow\",\"__typename\":\"Network\"},\"activationWall\":null,\"actionBasedWall\":null,\"browserNotifWallDeck\":null,\"viewInAppLink\":{\"id\":\"Vmlld0luQXBwTGlua0AwOjA=\"},\"facebookPuaPixel\":{\"eventsToFire\":[\"{\\\"name\\\": \\\"PageView\\\", \\\"metadata\\\": {}, \\\"isCustom\\\": false}\",\"{\\\"name\\\": \\\"Landing\\\", \\\"metadata\\\": {}, \\\"isCustom\\\": true}\"],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"facebookPuaViewer\":{\"uid\":null,\"id\":\"Vmlld2VyQDA6MA==\"},\"googlePuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"keyweePuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"twitterPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"awinPuaPixel\":{\"awinAwc\":null,\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"awinPuaViewer\":{\"uid\":null,\"id\":\"Vmlld2VyQDA6MA==\"},\"quoraPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"snapPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"snapPuaViewer\":{\"primaryEmail\":null,\"id\":\"Vmlld2VyQDA6MA==\"},\"tikTokPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"liveRampPixel\":{\"liverampHash\":\"319db6570bb7d9eb4ce7e8ea058b4c85\",\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"}},\"extensions\":{\"is_final\":true}}");window.ansFrontendGlobals.data.inlineQueryResults.next["c818677a71ee52a948df8a8ec246653cb5ab305dca610cdc075e6c663ae32ef9"] && window.ansFrontendGlobals.data.inlineQueryResults.next["c818677a71ee52a948df8a8ec246653cb5ab305dca610cdc075e6c663ae32ef9"]();
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};window.ansFrontendGlobals.data.inlineQueryResults.results["e84480196bc96c74a99c9a7e3c06c340e9b3e320cd8a773ba5a0d696ebf3f1f8"] = window.ansFrontendGlobals.data.inlineQueryResults.results["e84480196bc96c74a99c9a7e3c06c340e9b3e320cd8a773ba5a0d696ebf3f1f8"] || [];window.ansFrontendGlobals.data.inlineQueryResults.results["e84480196bc96c74a99c9a7e3c06c340e9b3e320cd8a773ba5a0d696ebf3f1f8"].push("{\"data\":{\"topic\":{\"suggestedTribeSuggestions\":[],\"id\":\"VG9waWNAMDo5NDg=\",\"__typename\":\"Topic\",\"numQuestions\":274951,\"url\":\"/topic/Machine-Learning\",\"tid\":948,\"name\":\"Machine Learning\",\"photoUrl\":\"https://qph.cf2.quoracdn.net/main-thumb-t-948-100-kfdrdbxmzmijrndlcvxdftbghuzsjpmc.jpeg\",\"defaultPhotoUrl\":\"https://qsf.cf2.quoracdn.net/-4-images.missing_photo.topic_icon_grey_filled.png-26-888a1612102f8cd5.png\",\"hasRelatedTopics\":true,\"hasLeaderboard\":true,\"relatedTopics\":[{\"id\":\"VG9waWNAMDoyMzA3\",\"__typename\":\"Topic\",\"numFollowers\":2730425,\"url\":\"/topic/Artificial-Intelligence\",\"isSensitive\":false,\"tid\":2307,\"name\":\"Artificial Intelligence\",\"isFollowing\":false,\"photoUrl\":\"https://qph.cf2.quoracdn.net/main-thumb-t-2307-100-tgwpfzgzdpnbkxjhrhzjzisqgaazhuxl.jpeg\"},{\"id\":\"VG9waWNAMDo3MTU5\",\"__typename\":\"Topic\",\"numFollowers\":747755,\"url\":\"/topic/Deep-Learning\",\"isSensitive\":false,\"tid\":7159,\"name\":\"Deep Learning\",\"isFollowing\":false,\"photoUrl\":\"https://qph.cf2.quoracdn.net/main-thumb-t-7159-100-vsnghaharbpvuobjoxdxslkcmdlpgrxt.jpeg\"},{\"id\":\"VG9waWNAMDo5ODA=\",\"__typename\":\"Topic\",\"numFollowers\":10122611,\"url\":\"/topic/Computer-Science\",\"isSensitive\":false,\"tid\":980,\"name\":\"Computer Science\",\"isFollowing\":false,\"photoUrl\":\"https://qph.cf2.quoracdn.net/main-thumb-t-980-100-H0buhDed9OV3rFiJlV9gj5ZOHtCovmDU.jpeg\"},{\"id\":\"VG9waWNAMDo0NzE3\",\"__typename\":\"Topic\",\"numFollowers\":529163,\"url\":\"/topic/Artificial-Neural-Networks\",\"isSensitive\":false,\"tid\":4717,\"name\":\"Artificial Neural Networks\",\"isFollowing\":false,\"photoUrl\":\"https://qph.cf2.quoracdn.net/main-thumb-t-4717-100-78grnIivpaUD7B2Ip7b5LAQFTJaYvqYP.jpeg\"},{\"id\":\"VG9waWNAMDo0MDc2Nw==\",\"__typename\":\"Topic\",\"numFollowers\":700765,\"url\":\"/topic/Artificial-General-Intelligence\",\"isSensitive\":false,\"tid\":40767,\"name\":\"Artificial General Intelligence\",\"isFollowing\":false,\"photoUrl\":\"https://qph.cf2.quoracdn.net/main-thumb-t-40767-100-qzvptmkcfzobsenodnfcvgyullyybvro.jpeg\"},{\"id\":\"VG9waWNAMDo2NDY2\",\"__typename\":\"Topic\",\"numFollowers\":819192,\"url\":\"/topic/Data-Science\",\"isSensitive\":false,\"tid\":6466,\"name\":\"Data Science\",\"isFollowing\":false,\"photoUrl\":\"https://qph.cf2.quoracdn.net/main-thumb-t-6466-100-kFicxKIQ4QAkRdD4Z7spmGaORM8GeLHi.jpeg\"},{\"id\":\"VG9waWNAMDo3Mzk0\",\"__typename\":\"Topic\",\"numFollowers\":407731,\"url\":\"/topic/Data-Mining\",\"isSensitive\":false,\"tid\":7394,\"name\":\"Data Mining\",\"isFollowing\":false,\"photoUrl\":\"https://qph.cf2.quoracdn.net/main-thumb-t-7394-100-PBpn3RALoNmT4WO9LhwNOflez38an6ih.jpeg\"},{\"id\":\"VG9waWNAMDo2NDIw\",\"__typename\":\"Topic\",\"numFollowers\":281965,\"url\":\"/topic/Classification-machine-learning\",\"isSensitive\":false,\"tid\":6420,\"name\":\"Classification (machine learning)\",\"isFollowing\":false,\"photoUrl\":\"https://qph.cf2.quoracdn.net/main-thumb-t-6420-100-V5jj5fEEQbS3fBlXrT7fQxL2ekua4kSV.jpeg\"},{\"id\":\"VG9waWNAMDoxMjA1\",\"__typename\":\"Topic\",\"numFollowers\" ...
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};window.ansFrontendGlobals.data.inlineQueryResults.results["2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e"] = window.ansFrontendGlobals.data.inlineQueryResults.results["2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e"] || [];window.ansFrontendGlobals.data.inlineQueryResults.results["2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e"].push("{\"data\":{\"viewer\":{\"id\":\"Vmlld2VyQDA6MA==\",\"__typename\":\"Viewer\",\"isGdprApplicable\":false,\"userNameUseJapaneseEditor\":false,\"signupId\":\"P8EnYHS9AM3XV9iscCTnOg==_1665542780216398\",\"facebookAuthNonce\":null},\"loginShouldShowLogoutAll\":false},\"label\":\"SignupWallWrapper_queryRoot$defer$SignupWall_queryRoot\",\"path\":[],\"extensions\":{\"is_final\":true}}");window.ansFrontendGlobals.data.inlineQueryResults.next["2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e"] && window.ansFrontendGlobals.data.inlineQueryResults.next["2f4b362fb07aa975cd9c3573102db1c51e04af257ff77a36e850ac2392f1696e"]();
#   </script>
#   <script type="text/javascript">
#    window.executeAfterEntryjsLoaded(
#                         () => window.setTimingData({"server_time":394.431,"total_worker_time":490.175,"window_id":"react_jabzrwppznirkdfv","page":394.431,"request":409.723}));
#
#                     window.executeAfterEntryjsLoaded(
#                         () => window.reportPageSpeedData({"standard":{"server_side":1000,"e2e":null,"owner":30,"server_side_goal":600}}));
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## 2. Selenium WebDriver
# - Selenium WebDriver is one of the most popular tools for **Web UI Automation**
# - It uses the WebDriver protocol to control a web browser, like Chrome, Firefox or Safari.
# - Selenium is really useful when you have to perform action on a website such as:
#   - clicking on buttons
#   - filling forms
#   - scrolling
#   - taking a screenshot
#   - execute Javascript code.
# - Installation:
#   - Install Selenium package:
#     - pip install selenium
#   - Download a webdirver based on your browser: https://www.selenium.dev/documentation/en/getting_started_with_webdriver/third_party_drivers_and_plugins/. `Be sure to download the latest version!`
#   - Place the webdrive (unzip it if the download is zipped) in a folder, e.g. a sub-folder called `drive` under the current working folder. When call selenium, point the `executable_path` parameter to that folder.
#   - mac users follow this https://stackoverflow.com/questions/43528944/python-browser-with-mac-error-chromedriver-executable-needs-to-be-in-path
# - syntax:
#     check out https://www.selenium.dev/documentation/webdriver/elements/finders/

# %% [markdown]
# ## 3. Use of Selenium WebDriver
#
# ### 3.1. **Navigating** (similar to beautifulsoup, but using different syntax)
#   * navigate to a link
#   * find elements by id, name, xpath, CSS selectors
#     * check this for detailed syntax: https://www.selenium.dev/documentation/webdriver/locating_elements/
#
# |    | requests/BeautifulSoup | Selenium WebDriver |
# | -- |:------------------      |:-----------|
# | Navigate to a link |   `requests.get(url)`           | `driver.get(url)`    |
# | find elements  | `soup.select()` | `driver.find_element(By.ID, "")`<br> `driver.find_elements(By.TAG_NAME, "")` <br> `driver.find_element(By.CLASS_NAME,"")` <br>`driver.find_element(By.CSS_SELECTOR,"")`<br>`driver.find_element(By.XPATH,"")` ...|

# %%
# Exercise 3.1.1 Scrape using Selenium

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions 

# for Chrome/Firefox browser, do the following
# (1) find the path where you save the webdriver 
# executable_path = 'driver/geckodriver'
# (2) initial the driver(executable_path=executable_path)
# driver=webdriver.Firefox()
# Selenium is built in in Safari
# Make sure you enable "Develop -> Allow Remote Automation"
# driver = webdriver.Safari()

driver = webdriver.Chrome()

# send a request
driver.get('https://www.quora.com/topic/Machine-Learning')

# you should see a window open

# %%
# Exercise 3.1.2. Select truncated text using Selenium

# get all questions using css selector
# find the first "more"

# try this
questions=driver.\
   find_elements(By.CSS_SELECTOR,"span.q-box.qu-userSelect--text")
    

for i, q in enumerate(questions):
    print(i, q.text)
    print("\n")
    
# close the webdriver. 
driver.quit()
# Out:
# 0 Why do many data scientists complain that Kaggle's data is clean even though it's usually in 5-6 separate files with tons of features missing a lot of values?
#
#
# 1 I've recently completed my PhD in statistics. I would like to get a second PhD in machine learning. Am I in the correct way? What should I do?
#
#
# 2 Why is deep learning so easy?
#
#
# 3 What do you think of Noam Chomsky's view on modern AI?
#
#
# 4 Is data science just simply cleaning data and putting it into a model with already built in algorithms?
#
#
# 5 What do people think of the TensorFlow sucks article?
#
#
# 6 What is an intuitive explanation of singular value decomposition (SVD)?
#
#
# 7 What benefit did Google gain by giving its unique and invaluable internal treasures like Kubernetes and TensorFlow to the open source community where even competitors can benefit?
#
#
# 8 How long did it take you to learn machine learning to get a job?
#
#
# 9 What is something about the field of data science that only a professional would know?
#
#
# 10 What is it like to be a machine learning researcher at Facebook?
#
#
# 11 What is mirror descent and how is it different from gradient descent?
#
#
# 12 How do I get started in machine learning theory and programming?
#
#
# 13 What does it mean that we don't really understand what happens in neural networks?
#
#
# 14 What's something about machine learning that only a professional would know?
#
#
# 15 What are the must-read papers on data mining and machine learning?
#
#
# 16 What does it mean that we don't really understand what happens in neural networks?
#
#
# 17 What are kernels in machine learning and SVM and why do we need them?
#
#
# 18 Is machine learning plateauing?
#
#
# 19 How are machine learning projects managed?

# %% [markdown]
# ### 3.2. Simulates users' actions performed in a web browser.
#
#   - click a button
#     * e.g. submit_button.click()
#   - fill a form
#     * e.g. text_box.send_keys("enter some text")
#   - scroll page down or up
#     * e.g. body.send_keys(Keys.PAGE_DOWN)
#   - move between windows and frames
#     * e.g. driver.switch_to_frame("frameName")
#   ...
#   - For details see https://selenium-python.readthedocs.io/navigating.html

# %%
# automatic search

import time
driver = webdriver.Chrome()

driver.get('https://www.google.com/');

time.sleep(5) 

#try this
search_box = driver.find_element(By.TAG_NAME,'input')

from selenium.webdriver.common.keys import Keys

search_box.clear()

search_box.send_keys("Selenium" + Keys.ENTER)

# %%
# 3.2.1 Simulate "click"
# Click "more" link to get full answer

#driver = webdriver.Firefox(executable_path=executable_path)
#driver.get('https://www.quora.com/topic/Machine-Learning')

driver = webdriver.Chrome()
driver.get('https://www.quora.com/topic/Machine-Learning')

driver.implicitly_wait(10)  # set implict wait

# locate a "more" link by css selector
more_link=driver.find_elements(By.CSS_SELECTOR,"div.q-text.qu-cursor--pointer.qt_read_more")[0]


# click the link element, must contain a link
more_link.click()

# Check browser to see an expanded answer

# %%
driver.quit()

# %%
# Scroll down to load more questions
import time

driver = webdriver.Chrome()
driver.get('https://www.quora.com/topic/Machine-Learning')

# scroll down 5 times
for i in range(5):
    driver.execute_script("window.scrollTo(0, \
    document.body.scrollHeight);")
    
    # wait for the content to be loaded
    time.sleep(2)   

questions=driver.find_elements(By.CSS_SELECTOR,"span.q-box.qu-userSelect--text")
    
for i, q in enumerate(questions):
    print(i, q.text)
    print("\n")
# Out:
# 0 I've recently completed my PhD in statistics. I would like to get a second PhD in machine learning. Am I in the correct way? What should I do?
#
#
# 1 Why is deep learning so easy?
#
#
# 2 As a data scientist, how can I transition to be a machine learning engineer?
#
#
# 3 What do you think of Noam Chomsky's view on modern AI?
#
#
# 4 Is data science just simply cleaning data and putting it into a model with already built in algorithms?
#
#
# 5 What do people think of the TensorFlow sucks article?
#
#
# 6 What is an intuitive explanation of singular value decomposition (SVD)?
#
#
# 7 What benefit did Google gain by giving its unique and invaluable internal treasures like Kubernetes and TensorFlow to the open source community where even competitors can benefit?
#
#
# 8 How long did it take you to learn machine learning to get a job?
#
#
# 9 What is something about the field of data science that only a professional would know?
#
#
# 10 What is it like to be a machine learning researcher at Facebook?
#
#
# 11 What is mirror descent and how is it different from gradient descent?
#
#
# 12 How do I get started in machine learning theory and programming?
#
#
# 13 What does it mean that we don't really understand what happens in neural networks?
#
#
# 14 What's something about machine learning that only a professional would know?
#
#
# 15 What are the must-read papers on data mining and machine learning?
#
#
# 16 What does it mean that we don't really understand what happens in neural networks?
#
#
# 17 What are kernels in machine learning and SVM and why do we need them?
#
#
# 18 Is machine learning plateauing?
#
#
# 19 How are machine learning projects managed?
#
#
# 20 What is the best way to start learning machine learning and deep learning without taking any online courses?
#
#
# 21 How do you explain Machine Learning and Data Mining to non Computer Science people?
#
#
# 22 Which should I learn first for data science, Python or statistics?
#
#
# 23 What are some software and skills that every data scientist should know (excluding R, Matlab, and Hadoop)? Also, what are some resources for learning Hadoop?
#
#
# 24 What are three machine learning algorithms you would recommend an aspiring data scientist learn thoroughly before moving onto others?
#
#
# 25 How often do you use label encoding in your work as a data scientist?
#
#
# 26 How can Convolutional Neural Networks be fooled so easily (like mistaking a cat for a dog)?
#
#
# 27 What are some embarrassing statistics mistakes that people with fancy credentials often make?
#
#
# 28 Are you a self-taught machine learning engineer? If yes, how did you do it, and how long did it take you?
#
#
# 29 Andrew Ng's courses are old and I'm not sure if they’re useful now. So what's the best course for beginners on Machine Learning in 2018?
#
#
# 30 What are the biggest misconceptions about AI?
#
#
# 31 In movies based on real life, do directors use AI, computer vision etc., to pick the actors who most resemble the historical characters?
#
#
# 32 Are there any very popular machine learning algorithms in research that very few data scientists use? If so, why?
#
#
# 33 Is it getting harder to break into machine learning?
#
#
# 34 Where is Machine Learning or Artificial Intelligence adding value to your company?
#
#
# 35 What is the future of performance enhancement?
#
#
# 36 How does Boston Dynamics use AI/machine learning?
#
#
# 37 What does ChatGPT give incorrect and unreliable results to simple arithmetic problems (e.g. it gave me three different incorrect answers to 13345*6748)? We've had software that can accurately do arithmetic for decades, so why can't an advanced AI?
#
#
# 38 Is a neural network actually a good model of how the brain works?
#
#
# 39 How did Spotify get so good at machine learning? Was machine learning important from the start, or did they catch up over time?
#
#
# 40 What is hard sigmoid in artificial neural networks? Why is it faster than standard sigmoid? Are there any disadvantages over the standard sigmoid?
#
#
# 41 As an ML engineer at Quora, have you ever implemented a research article in machine learning to solve a technical or product problem?
#
#
# 42 How does one operationalize a machine learning ranking system, from an organization and an engineering management point of view? How do organizations make sure that they're running smoothly and improving? How are goals defined and by whom?
#
#
# 43 What are the toughest neural networks and deep learning interview questions?
#
#
# 44 What are the dark sides of a career in AI/machine learning?
#
#
# 45 What is the creepiest thing any AI has done so far?
#
#
# 46 What are some relatively unknown but powerful data science / machine learning tricks?
#
#
# 47 What are some must know tricks in the field of data science that most people are oblivious to?
#
#
# 48 What fallacies do amateur machine learning engineers make that experienced ones don't?
#
#
# 49 Should you spend money to buy a good GPU for studying deep learning (I’m not referring to production runs)?
#
#
# 50 What data science or machine learning problem are you trying to solve right now?
#
#
# 51 What's the silliest application of machine learning you have seen?
#
#
# 52 What are the best practices for building something like a news feed?
#
#
# 53 Can deep learning predict the digits of Pi?
#
#
# 54 How can an AI train itself if no one is telling it if its answer is correct or wrong?
#
#
# 55 Are any areas of the English language still out of reach for machine translation?
#
#
# 56 Is it worth doing the Machine Learning Crash Course by Google or is Andrew Ng’s Coursera course better?
#
#
# 57 Why did it take so long to invent the backpropagation algorithm? Isn't it just a straightforward (albeit cumbersome) application of the chain rule?
#
#
# 58 So many people are learning machine learning. What should I do to stand out?
#
#
# 59 What do natural language processing algorithms look like?

# %%
driver.quit()

# %% [markdown]
# ### 3.3. Wait
#   - Because of the use of AJAX technologies, web elements often load at different time intervals.
#   - This makes locating elements difficult.
#     - if an element is not loaded,  a locating function will raise an ElementNotVisibleException exception.
#   - Two types of waits
#     - `implicit`: When a Webdriver locates for any element, but the element is not available, instead of throwing "No Such Element Exception" immediately, the Webdriver waits for a certain amount of time. By the time it is still not available, then the error is thrown.
#       * Implicit wait is set at the driver level and applies to <font color='blue'>any locating function</font>
#     - `explicit`: WebDriver waits for a certain condition to occur before proceeding further with execution
#       * Explicit wait is set at <font color='blue'>each locating function</font>
#     - check out https://www.selenium.dev/documentation/webdriver/waits/

# %% [markdown]
# Assume you're looking for a question, but you're not sure if this question has been loaded into the page
# - Case 1: If this question is not in the page, you get an error immediately
# - Case 2: If it takes time to load the question, use implict wait to wait for some time
# - Case 3: You can keep scroll down until the question has been loaded or max tries reached
#     - Use `try ... else` block to handle the exception more elegently

# %%
# If the element is not there, you'll see an error immediately

#driver = webdriver.Safari()
driver = webdriver.Chrome()
driver.get('https://www.quora.com/topic/Machine-Learning')

q = driver.find_elements(By.CSS_SELECTOR,'a[href="https://www.quora.com/How-can-Convolutional-Neural-Networks-be-fooled-so-easily-like-mistaking-a-cat-for-a-dog"]')

print(q.text)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-5cf57f868656> in <module>
#       7 q = driver.find_elements(By.CSS_SELECTOR,'a[href="https://www.quora.com/How-can-Convolutional-Neural-Networks-be-fooled-so-easily-like-mistaking-a-cat-for-a-dog"]')
#       8
# ----> 9 print(q.text)
#      10 driver.quit()
#
# AttributeError: 'list' object has no attribute 'text'

# %%
driver.quit()

# %%
# If the element is not there, you'll see an error after the waiting

driver = webdriver.Chrome()
driver.get('https://www.quora.com/topic/Machine-Learning')

driver.implicitly_wait(10)

q = driver.find_elements(By.CSS_SELECTOR,'a[href="https://www.quora.com/How-can-Convolutional-Neural-Networks-be-fooled-so-easily-like-mistaking-a-cat-for-a-dog"]')
print(q.text)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-00c10d56f68e> in <module>
#       7
#       8 q = driver.find_elements(By.CSS_SELECTOR,'a[href="https://www.quora.com/How-can-Convolutional-Neural-Networks-be-fooled-so-easily-like-mistaking-a-cat-for-a-dog"]')
# ----> 9 print(q.text)
#      10 driver.quit()
#
# AttributeError: 'list' object has no attribute 'text'

# %%
driver.quit()

# %%
# If the element is not there, 
# you keep scrolling down until the element is there
# or scrolling for max number of times
# try except can catch the error
# https://selenium-python.readthedocs.io/waits.html#explicit-waits

driver = webdriver.Chrome()
driver.get('https://www.quora.com/topic/Machine-Learning')

found = False
max_try = 10  # max number of scroll-downs
cnt = 0

while not found and cnt < max_try:
    
    try:
        # This waits up to 5 seconds before throwing a TimeoutException 
        # unless it finds the element to return 
        
        q = WebDriverWait(driver,5).until(\
                    expected_conditions.\
                    presence_of_element_located((By.CSS_SELECTOR, \
                    # An expectation for checking that an element is present on the DOM of a page.
                   'a[href="https://www.quora.com/How-can-Convolutional-Neural-Networks-be-fooled-so-easily-like-mistaking-a-cat-for-a-dog"]')))
        
        found = True
        print(q.text)

    except:     # item not there yet
        
        driver.execute_script("window.scrollTo(0, \
        document.body.scrollHeight);")
     
        cnt += 1
        
driver.quit()
# Out:
# How can Convolutional Neural Networks be fooled so easily (like mistaking a cat for a dog)?
