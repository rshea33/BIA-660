# %% [markdown]
# # <center>Pandas DataFrames</center>
# References:
# * https://pandas.pydata.org/pandas-docs/stable/10min.html

# %% [markdown]
# ## 3. Pandas package and DataFrame
# - Next to Numpy, Pandas is one of the most widely used Python library
# - Two commonly used data structures:
#   * **Series**: a one-dimensional labeled array
#   * **DataFrame**: two-dimensional labeled data structure with columns
# - Labeling
#   * **index**: the name of each row
#   * **column name**: the name of each column

# %% [markdown]
# ### 3.1 Creating DataFrames and viewing data

# %%
# enable interactiveShell
# so that Jupyter will display variables or 
# unassigned output of a statemen 
# without the need for a print statement

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import numpy as np

pd.options.display.float_format = '{:,.2f}'.format

# %%
# Exercise 3.1.1 Create a Pandas series

# create a series from a list 
# or a one-dimensional array
s=pd.Series(['01','02','10','50','30'], index=["1","2","3","4","5"])
s
s.values
# Out:
# 1    01
# 2    02
# 3    10
# 4    50
# 5    30
# dtype: object
# array(['01', '02', '10', '50', '30'], dtype=object)

# %%
# Exercise 3.1.2 Create a Pandas dataframe

# create a dataframe from a random array
# note the labels for rows (index) and columns names
df_edu= pd.DataFrame(np.random.randint(60,100, (5,4)), \
                  index=s, columns=['A','B','C','D'])
df_edu
# Out:
#      A   B   C   D
# 01  82  69  72  86
# 02  73  73  81  93
# 10  86  84  70  60
# 50  65  81  95  83
# 30  68  86  98  89

# %%
# Exercise 3.1.3. add new columns

# add a new column "E"
df_edu["DEPT"]=['CS','BIA','IS','BIA','BIA']
df_edu
# Out:
#      A   B   C   D DEPT
# 01  82  69  72  86   CS
# 02  73  73  81  93  BIA
# 10  86  84  70  60   IS
# 50  65  81  95  83  BIA
# 30  68  86  98  89  BIA

# %%
# Exercise 3.1.4. Create a dataframe

x=[(1, 0.8, 'NJ'), (3, 0.7, 'NY'), (2, 0.65, 'PA'),(3, 0.25, 'PA'), \
   (2, 0.32, 'NJ'),(4, 0.95, 'PA'),(1, 0.44, 'NY'), (4, 0.15, 'NY')]

# Create a dataframe from the list of tuples 
# quarter, income, state
# show statistics of income column

col=("quarter", "income", "state")
df_econ=pd.DataFrame(np.array(x), columns=list(col))
df_econ
# Out:
#   quarter income state
# 0       1    0.8    NJ
# 1       3    0.7    NY
# 2       2   0.65    PA
# 3       3   0.25    PA
# 4       2   0.32    NJ
# 5       4   0.95    PA
# 6       1   0.44    NY
# 7       4   0.15    NY

# %%
# Exercise 3.1.5. View DataFrame index, columns, and values

df= pd.read_csv('iris.csv', header=0)

# get first two rows
df.head(2)

# get last three rows
df.tail(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    type   soil
# 0          4.50         2.30          1.30         0.30  Setosa  Shade
# 1          4.40         2.90          1.40         0.20  Setosa  Shade
#      sepal_length  sepal_width  petal_length  petal_width       type   soil
# 147          7.20         3.60          6.10         2.50  Virginica  Shade
# 148          7.70         3.80          6.70         2.20  Virginica  Shade
# 149          7.90         3.80          6.40         2.00  Virginica  Shade

# %%
# get a column 
df.sepal_length[0:2]
set(df['type'])
set(df.soil)

# df index
print("print df index")
df.index

print("print df column names")
df.columns

print("print df values")
df.values[0:2,0:2]

type(df.values) # values are numpy array
type(df.soil) # series
df.values.shape # shape of the array

df.shape
# Out:
# 0   4.50
# 1   4.40
# Name: sepal_length, dtype: float64
# {'Setosa', 'Versicolour', 'Virginica'}
# {'Shade', 'Sun'}
# print df index
# RangeIndex(start=0, stop=150, step=1)
# print df column names
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'type',
#        'soil'],
#       dtype='object')
# print df values
# array([[4.5, 2.3],
#        [4.4, 2.9]], dtype=object)
# numpy.ndarray
# pandas.core.series.Series
# (150, 6)
# (150, 6)

# %%
# Exercise 3.1.6. Show statistics of each column

df.describe()
df.describe().petal_width

# the statistics is also a dataframe
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count        150.00       150.00        150.00       150.00
# mean           5.84         3.06          3.76         1.20
# std            0.83         0.44          1.77         0.76
# min            4.30         2.00          1.00         0.10
# 25%            5.10         2.80          1.60         0.30
# 50%            5.80         3.00          4.35         1.30
# 75%            6.40         3.30          5.10         1.80
# max            7.90         4.40          6.90         2.50
# count   150.00
# mean      1.20
# std       0.76
# min       0.10
# 25%       0.30
# 50%       1.30
# 75%       1.80
# max       2.50
# Name: petal_width, dtype: float64

# %% [markdown]
# ### 3.2. DataFrame Sorting
# - Dataframes can be sorted by
#   * index
#   * one or more columns

# %%
# Exercise 3.2.1. Sorting

# sort by index
print("sort by index labels")
df.sort_index(axis=0, ascending=False)

# sort by column names
print("\nsort by column names")
df.sort_index(axis=1, ascending=False)
# Out:
# sort by index labels
#      sepal_length  sepal_width  petal_length  petal_width       type   soil
# 149          7.90         3.80          6.40         2.00  Virginica  Shade
# 148          7.70         3.80          6.70         2.20  Virginica  Shade
# 147          7.20         3.60          6.10         2.50  Virginica  Shade
# 146          6.20         3.40          5.40         2.30  Virginica  Shade
# 145          6.30         3.40          5.60         2.40  Virginica  Shade
# ..            ...          ...           ...          ...        ...    ...
# 4            4.30         3.00          1.10         0.10     Setosa    Sun
# 3            4.80         3.00          1.40         0.10     Setosa    Sun
# 2            4.90         3.00          1.40         0.20     Setosa  Shade
# 1            4.40         2.90          1.40         0.20     Setosa  Shade
# 0            4.50         2.30          1.30         0.30     Setosa  Shade
#
# [150 rows x 6 columns]
# sort by column names
#           type   soil  sepal_width  sepal_length  petal_width  petal_length
# 0       Setosa  Shade         2.30          4.50         0.30          1.30
# 1       Setosa  Shade         2.90          4.40         0.20          1.40
# 2       Setosa  Shade         3.00          4.90         0.20          1.40
# 3       Setosa    Sun         3.00          4.80         0.10          1.40
# 4       Setosa    Sun         3.00          4.30         0.10          1.10
# ..         ...    ...          ...           ...          ...           ...
# 145  Virginica  Shade         3.40          6.30         2.40          5.60
# 146  Virginica  Shade         3.40          6.20         2.30          5.40
# 147  Virginica  Shade         3.60          7.20         2.50          6.10
# 148  Virginica  Shade         3.80          7.70         2.20          6.70
# 149  Virginica  Shade         3.80          7.90         2.00          6.40
#
# [150 rows x 6 columns]

# %%
# Exercise 3.2.1. Sorting

# sort the values by specifc columns
# to sort by A  use by='A'
# for multiple columns, use a list
print("\n1. Sort the values by column sepal width")
df.sort_values(by='sepal_width', ascending=False)

print("\n2. Sort the values by columns type and sepal width")
df.sort_values(by=['type','sepal_width'], ascending=[False,False])
# Out:
# 1. Sort the values by column sepal width
#      sepal_length  sepal_width  petal_length  petal_width         type   soil
# 49           5.70         4.40          1.50         0.40       Setosa  Shade
# 48           5.50         4.20          1.40         0.20       Setosa  Shade
# 47           5.20         4.10          1.50         0.10       Setosa    Sun
# 46           5.80         4.00          1.20         0.20       Setosa  Shade
# 45           5.40         3.90          1.30         0.40       Setosa    Sun
# ..            ...          ...           ...          ...          ...    ...
# 55           5.00         2.30          3.30         1.00  Versicolour  Shade
# 52           6.20         2.20          4.50         1.50  Versicolour  Shade
# 51           6.00         2.20          4.00         1.00  Versicolour  Shade
# 100          6.00         2.20          5.00         1.50    Virginica    Sun
# 50           5.00         2.00          3.50         1.00  Versicolour  Shade
#
# [150 rows x 6 columns]
# 2. Sort the values by columns type and sepal width
#      sepal_length  sepal_width  petal_length  petal_width       type   soil
# 148          7.70         3.80          6.70         2.20  Virginica  Shade
# 149          7.90         3.80          6.40         2.00  Virginica  Shade
# 147          7.20         3.60          6.10         2.50  Virginica  Shade
# 145          6.30         3.40          5.60         2.40  Virginica  Shade
# 146          6.20         3.40          5.40         2.30  Virginica  Shade
# ..            ...          ...           ...          ...        ...    ...
# 5            5.00         3.00          1.60         0.20     Setosa    Sun
# 6            4.40         3.00          1.30         0.20     Setosa    Sun
# 7            4.80         3.00          1.40         0.30     Setosa    Sun
# 1            4.40         2.90          1.40         0.20     Setosa  Shade
# 0            4.50         2.30          1.30         0.30     Setosa  Shade
#
# [150 rows x 6 columns]

# %% [markdown]
# ### 3.3 Value Selection
# - Values can be selected by
#   * column names and a list of column names
#   * index **labels** (**loc** property)
#   * index **position** (**iloc** property)
#   * indexes and columns together
#   * uses **xs** select data at a particular level of a MultiIndex
#   * conditions (boolean index)

# %%
# Exercise 3.3.1 Selecting columns

# get multiple columns
print("\n2. Get multiple columns")
df[['type','petal_width']]
# Out:
# 2. Get multiple columns
#           type  petal_width
# 0       Setosa         0.30
# 1       Setosa         0.20
# 2       Setosa         0.20
# 3       Setosa         0.10
# 4       Setosa         0.10
# ..         ...          ...
# 145  Virginica         2.40
# 146  Virginica         2.30
# 147  Virginica         2.50
# 148  Virginica         2.20
# 149  Virginica         2.00
#
# [150 rows x 2 columns]

# %%
# Exercise 3.3.2 select rows by index

# loc is label-based, which means that you have to specify rows and columns based on their row and column labels.
# get a specific row by index
print("1. Get first row by index label")
df.loc[1]

# get multiple rows by index list
print("2. Get multiple rows by index list")
df.loc[[1,60]]
# Out:
# 1. Get first row by index label
# sepal_length      4.40
# sepal_width       2.90
# petal_length      1.40
# petal_width       0.20
# type            Setosa
# soil             Shade
# Name: 1, dtype: object
# 2. Get multiple rows by index list
#     sepal_length  sepal_width  petal_length  petal_width         type   soil
# 1           4.40         2.90          1.40         0.20       Setosa  Shade
# 60          6.30         2.50          4.90         1.50  Versicolour  Shade

# %%
# Exercise 3.3.3. select rows by position

# iloc is integer position-based, so you have to specify rows and columns by their integer position values
# select the first row by position
print("1. Select the first row by position")
df.iloc[0]

# select the first two rows by position
print("2. Select the first two rows by position list")
df.iloc[0:2]
# Out:
# 1. Select the first row by position
# sepal_length      4.50
# sepal_width       2.30
# petal_length      1.30
# petal_width       0.30
# type            Setosa
# soil             Shade
# Name: 0, dtype: object
# 2. Select the first two rows by position list
#    sepal_length  sepal_width  petal_length  petal_width    type   soil
# 0          4.50         2.30          1.30         0.30  Setosa  Shade
# 1          4.40         2.90          1.40         0.20  Setosa  Shade

# %%
# Exercise 3.3.4. select on multiple axes 

# select the 1st and 3rd row, 3rd and 4th columns
df.iloc[[0,2], 2:4] #index

df.loc[[0,2], ['petal_length','petal_width']] # labels

# however, when you iloc, don't use column names, e.g.
# df.iloc[[0,2], ['petal_length','petal_width']]


# Select last three rows, 2nd and 5th columns
df.iloc[-3:, [1,4]]
# Out:
#    petal_length  petal_width
# 0          1.30         0.30
# 2          1.40         0.20
#    petal_length  petal_width
# 0          1.30         0.30
# 2          1.40         0.20
#      sepal_width       type
# 147         3.60  Virginica
# 148         3.80  Virginica
# 149         3.80  Virginica

# %%
# Exercise 3.3.5. Select by condition (Boolean index)

print("Get data where column sepal width is greater than 3.6")
df.sepal_width>3.6
df[df.sepal_width>3.6]

# ***Don't forget the parentheses () around each condition****
# also note "&", not "and". "and" evaluates boolean 
print("Get data where sepal width is greater than 3.6 and type if setosa")
df[(df.sepal_width>3.6) & (df.type=='Setosa')]


# See what you get if ignore "()" around the condition. Operator precedence. 

# condition on index 
# note the **isin** function to select a range
print("Rows with index in ['1','10','20','40'] and sepal width > 3.6")
df[(df.index.isin([1,10,20,40])) & (df.sepal_width>3.6)]

# select the rows for Setosa and Virginica and petal width > 2.4
df[(df.petal_width>2.4)& (df["type"].isin(["Setosa","Virginica"]))]
# Out:
# Get data where column sepal width is greater than 3.6
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148     True
# 149     True
# Name: sepal_width, Length: 150, dtype: bool
#      sepal_length  sepal_width  petal_length  petal_width       type   soil
# 37           5.40         3.70          1.50         0.20     Setosa    Sun
# 38           5.10         3.70          1.50         0.40     Setosa    Sun
# 39           5.30         3.70          1.50         0.20     Setosa  Shade
# 40           5.70         3.80          1.70         0.30     Setosa    Sun
# 41           5.10         3.80          1.50         0.30     Setosa    Sun
# 42           5.10         3.80          1.90         0.40     Setosa  Shade
# 43           5.10         3.80          1.60         0.20     Setosa    Sun
# 44           5.40         3.90          1.70         0.40     Setosa    Sun
# 45           5.40         3.90          1.30         0.40     Setosa    Sun
# 46           5.80         4.00          1.20         0.20     Setosa  Shade
# 47           5.20         4.10          1.50         0.10     Setosa    Sun
# 48           5.50         4.20          1.40         0.20     Setosa  Shade
# 49           5.70         4.40          1.50         0.40     Setosa  Shade
# 148          7.70         3.80          6.70         2.20  Virginica  Shade
# 149          7.90         3.80          6.40         2.00  Virginica  Shade
# Get data where sepal width is greater than 3.6 and type if setosa
#     sepal_length  sepal_width  petal_length  petal_width    type   soil
# 37          5.40         3.70          1.50         0.20  Setosa    Sun
# 38          5.10         3.70          1.50         0.40  Setosa    Sun
# 39          5.30         3.70          1.50         0.20  Setosa  Shade
# 40          5.70         3.80          1.70         0.30  Setosa    Sun
# 41          5.10         3.80          1.50         0.30  Setosa    Sun
# 42          5.10         3.80          1.90         0.40  Setosa  Shade
# 43          5.10         3.80          1.60         0.20  Setosa    Sun
# 44          5.40         3.90          1.70         0.40  Setosa    Sun
# 45          5.40         3.90          1.30         0.40  Setosa    Sun
# 46          5.80         4.00          1.20         0.20  Setosa  Shade
# 47          5.20         4.10          1.50         0.10  Setosa    Sun
# 48          5.50         4.20          1.40         0.20  Setosa  Shade
# 49          5.70         4.40          1.50         0.40  Setosa  Shade
# Rows with index in ['1','10','20','40'] and sepal width > 3.6
#     sepal_length  sepal_width  petal_length  petal_width    type soil
# 40          5.70         3.80          1.70         0.30  Setosa  Sun
#      sepal_length  sepal_width  petal_length  petal_width       type   soil
# 142          6.30         3.30          6.00         2.50  Virginica  Shade
# 144          6.70         3.30          5.70         2.50  Virginica  Shade
# 147          7.20         3.60          6.10         2.50  Virginica  Shade

# %%
# Exercise 3.3.5. 
# create multi-index 
x1=df.groupby(['type',"soil"])[['petal_width',"sepal_width"]].mean() 
x1

# Select by multiple index, note the tuple, different from selecting indexes and columns.
x1.loc[('Setosa',"Shade")]

# select by xs, include the label
x1.xs('Setosa', level ="type")
# Out:
#                    petal_width  sepal_width
# type        soil
# Setosa      Shade         0.25         3.44
#             Sun           0.24         3.41
# Versicolour Shade         1.22         2.54
#             Sun           1.42         2.98
# Virginica   Shade         2.09         3.11
#             Sun           1.92         2.75
# petal_width   0.25
# sepal_width   3.44
# Name: (Setosa, Shade), dtype: float64
#        petal_width  sepal_width
# soil
# Shade         0.25         3.44
# Sun           0.24         3.41

# %%
# Exercise 3.3.7. 
# selection by condition

x = pd.DataFrame([[np.nan, 2, np.nan, 0], [3, 4, 6, 1],
                   [np.nan, np.nan, np.nan, 5], [5, 8, 2, 5]],
                   columns=list('ABCD'))
x
# check missing values
x1 = x.isnull()
x1
# Out:
#      A    B    C  D
# 0  NaN 2.00  NaN  0
# 1 3.00 4.00 6.00  1
# 2  NaN  NaN  NaN  5
# 3 5.00 8.00 2.00  5
#        A      B      C      D
# 0   True  False   True  False
# 1  False  False  False  False
# 2   True   True   True  False
# 3  False  False  False  False

# %%
# find rows that contain any missing values

c1 = x1.any(axis = 1)
c1    # Note c1 returns True/False on indexes

# delete rows that contain missing values
x.loc[-c1,:]
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool
#      A    B    C  D
# 1 3.00 4.00 6.00  1
# 3 5.00 8.00 2.00  5

# %%
# # find columns that contain any missing values

c2 = x1.any(axis = 0)
c2   # Note c2 return True/False on column names

x.loc[:, c2]
x.loc[:, -c2]
# Out:
# A     True
# B     True
# C     True
# D    False
# dtype: bool
#      A    B    C
# 0  NaN 2.00  NaN
# 1 3.00 4.00 6.00
# 2  NaN  NaN  NaN
# 3 5.00 8.00 2.00
#    D
# 0  0
# 1  1
# 2  5
# 3  5

# %% [markdown]
# ### 3.4.  Aggregation
# - Dataframes can support aggregation by groups very flexibly. Very useful for multilevel structures.
#   * count
#   * mean
#   * sum
#   * custom function

# %%
# Exercise 3.4.1 value counts 
# get counts of each value in a column

df.type.value_counts()
df.soil.value_counts()
# Out:
# Setosa         50
# Versicolour    50
# Virginica      50
# Name: type, dtype: int64
# Shade    78
# Sun      72
# Name: soil, dtype: int64

# %%
# Exercise 3.4.2 group by a column and aggregate

grouped=df.groupby(['type'])
grouped.size()  # get number of rows in each group
grouped.sum()   # sum by group
grouped.mean()  # mean by group
# Out:
# type
# Setosa         50
# Versicolour    50
# Virginica      50
# dtype: int64
#              sepal_length  sepal_width  petal_length  petal_width
# type
# Setosa             250.30       171.40         73.10        12.30
# Versicolour        296.80       138.50        213.00        66.30
# Virginica          329.40       148.70        277.60       101.30
#              sepal_length  sepal_width  petal_length  petal_width
# type
# Setosa               5.01         3.43          1.46         0.25
# Versicolour          5.94         2.77          4.26         1.33
# Virginica            6.59         2.97          5.55         2.03

# %%
# Exercise 3.4.3 multiple aggregation function

grouped= df.groupby(['type'])
grouped['sepal_width'].agg([ np.sum, np.mean, np.std, np.argmax])
# Out:
#                sum  mean  std  argmax
# type
# Setosa      171.40  3.43 0.38      49
# Versicolour 138.50  2.77 0.31      49
# Virginica   148.70  2.97 0.32      48

# %%
# Exercise 3.4.4 grouped by multiple columns 

grouped= df.groupby(['type',"soil"])
grouped.mean()

# note that the groupby columns are indexes now

# to remove multi-indexes and make them back to values
grouped.mean().reset_index()
# Out:
#                    sepal_length  sepal_width  petal_length  petal_width
# type        soil
# Setosa      Shade          5.05         3.44          1.44         0.25
#             Sun            4.97         3.41          1.48         0.24
# Versicolour Shade          5.70         2.54          4.01         1.22
#             Sun            6.15         2.98          4.49         1.42
# Virginica   Shade          6.80         3.11          5.70         2.09
#             Sun            6.24         2.75          5.32         1.92
#           type   soil  sepal_length  sepal_width  petal_length  petal_width
# 0       Setosa  Shade          5.05         3.44          1.44         0.25
# 1       Setosa    Sun          4.97         3.41          1.48         0.24
# 2  Versicolour  Shade          5.70         2.54          4.01         1.22
# 3  Versicolour    Sun          6.15         2.98          4.49         1.42
# 4    Virginica  Shade          6.80         3.11          5.70         2.09
# 5    Virginica    Sun          6.24         2.75          5.32         1.92

# %% [markdown]
# ### 3.5.  Pivot Table and Cross Tabulation
# - Pivot tables or cross tables can be computed easily with pandas
# - **pivot_table**: Calculate pivot tables from a data frame
# - **crosstab**: cross tabulation using any array-like objects (e.g. array, dataframe)
# - Difference between functions pivot_table and cross tabulation
#   * pivot_table expects input data to be ** a DataFrame**;
#   * crosstab can use array-like data objects, not necessarily dataframes.
#   * for pivot_table, the default aggregation function is **mean**, while for crosstab, the default aggregation function is **count**
# - **pivot tables and cross tables are also dataframes**

# %%
# Exercise 3.5.1 Pivot table
# for details, see https://pandas.pydata.org/pandas-docs/stable/generated/pandas.pivot_table.html

# parameters: 
# data: data source, 
# values: columns to be aggregated, use a list for multiple columns
# index: keys to group by as pivot table index (row)
# column: keys to group by as pivot table column
# aggfunc: aggregration function. default is mean

# Get mean of column A for students in each type and soil
pd.pivot_table(data=df, values=['petal_width'], index=['soil'], \
               columns='type',aggfunc=np.max)
# Out:
#       petal_width
# type       Setosa Versicolour Virginica
# soil
# Shade        0.50        1.60      2.50
# Sun          0.60        1.80      2.40

# %%
# Exercise 3.5.2 Pivot table by multiple index

# make one continuous variable into categories
df["sepal_length_cat"]= pd.qcut(df['sepal_length'],
                              q=[0, .25, .5, .75, 1],
                              labels=["very short","short","long","very long"])
df.sepal_length_cat.value_counts()

# Pivot by multiple rows or columns
y = pd.pivot_table(data=df, values=['petal_width'], index=['soil',"sepal_length_cat"], \
               columns='type')
y
y.index
# Out:
# very short    41
# short         39
# long          35
# very long     35
# Name: sepal_length_cat, dtype: int64
#                        petal_width
# type                        Setosa Versicolour Virginica
# soil  sepal_length_cat
# Shade very short              0.26        1.02       NaN
#       short                   0.23        1.18       NaN
#       long                     NaN        1.37      2.04
#       very long                NaN        1.40      2.11
# Sun   very short              0.23         NaN      1.70
#       short                   0.29        1.32      2.04
#       long                     NaN        1.47      1.80
#       very long                NaN        1.46      2.08
# MultiIndex([('Shade', 'very short'),
#             ('Shade',      'short'),
#             ('Shade',       'long'),
#             ('Shade',  'very long'),
#             (  'Sun', 'very short'),
#             (  'Sun',      'short'),
#             (  'Sun',       'long'),
#             (  'Sun',  'very long')],
#            names=['soil', 'sepal_length_cat'])

# %%
# 3.5.3. Get a cross table from a dataframe

# for details, check https://pandas.pydata.org/pandas-docs/stable/generated/pandas.crosstab.html

# parameters: 
# index: keys to group by as pivot table index (row)
# columns: keys to group by as pivot table column
# values: columns to be aggregated
# aggfunc: aggregration function. default is count

# count the observations in each type and each soil type
pd.crosstab(index=df.type, columns=df.soil)

# multiple index
pd.crosstab(index=[df.type, df.soil], columns=df.sepal_length_cat)

# Mean of petal width for each type and soil
pd.crosstab(index=df.type, columns=[df.soil], values=df.petal_width, \
            aggfunc=np.mean )
# Out:
# soil         Shade  Sun
# type
# Setosa          23   27
# Versicolour     24   26
# Virginica       31   19
# sepal_length_cat   very short  short  long  very long
# type        soil
# Setosa      Shade          16      7     0          0
#             Sun            20      7     0          0
# Versicolour Shade           4     12     7          1
#             Sun             0      8    10          8
# Virginica   Shade           0      0     9         22
#             Sun             1      5     9          4
# soil         Shade  Sun
# type
# Setosa        0.25 0.24
# Versicolour   1.22 1.42
# Virginica     2.09 1.92

# %%
# 3.5.3. Get a cross table from arrays 
x=np.array([[1,2,10],[3,4,8],[2,2,3],[3,1,4],[1,2,2]])
x
# count of cells by columns 1 and 2
pd.crosstab(index=x[:,0], columns=x[:,1],
           rownames=['col_1'], colnames=['col_2'])
# Out:
# array([[ 1,  2, 10],
#        [ 3,  4,  8],
#        [ 2,  2,  3],
#        [ 3,  1,  4],
#        [ 1,  2,  2]])
# col_2  1  2  4
# col_1
# 1      0  2  0
# 2      0  1  0
# 3      1  0  1

# %% [markdown]
# ### 3.6. Apply function to each row or each column of a dataframe
# - The apply function takes each row (axis=1) or each column (axis=0) of the dataframe as an input
# - Often **lambda** function (i.e. anonymous function, function without a name) is used
#    * lambda function: *<font color='green'>lambda x : expression of x </font>*
#    * it can be understood as: *<font color='green'> for x, return expression of x </font>*

# %%
# Exercise 3.6.1
# Find the percentage of column petal width
# in the sum of all four continuous variables for each row

df['petal_width_perc']=df.iloc[:,0:4].apply(lambda row: row['petal_width']/(sum(row)), axis=1)
df

# or you can define a function explicitly
def fun1(row):
    return row["petal_width"]/(sum(row))

df['petal_width_perc']=df.iloc[:,0:4].apply(fun1, axis=1)
df['petal_width_perc']

# how to normalize all columns?
k=df.iloc[:,0:4]
k.div(k.sum(axis=1), axis=0) # Return Floating division of series and other, element-wise
# Out:
#      sepal_length  sepal_width  petal_length  petal_width       type   soil  \
# 0            4.50         2.30          1.30         0.30     Setosa  Shade
# 1            4.40         2.90          1.40         0.20     Setosa  Shade
# 2            4.90         3.00          1.40         0.20     Setosa  Shade
# 3            4.80         3.00          1.40         0.10     Setosa    Sun
# 4            4.30         3.00          1.10         0.10     Setosa    Sun
# ..            ...          ...           ...          ...        ...    ...
# 145          6.30         3.40          5.60         2.40  Virginica  Shade
# 146          6.20         3.40          5.40         2.30  Virginica  Shade
# 147          7.20         3.60          6.10         2.50  Virginica  Shade
# 148          7.70         3.80          6.70         2.20  Virginica  Shade
# 149          7.90         3.80          6.40         2.00  Virginica  Shade
#
#     sepal_length_cat  petal_width_perc
# 0         very short              0.04
# 1         very short              0.02
# 2         very short              0.02
# 3         very short              0.01
# 4         very short              0.01
# ..               ...               ...
# 145             long              0.14
# 146             long              0.13
# 147        very long              0.13
# 148        very long              0.11
# 149        very long              0.10
#
# [150 rows x 8 columns]
# 0     0.04
# 1     0.02
# 2     0.02
# 3     0.01
# 4     0.01
#       ...
# 145   0.14
# 146   0.13
# 147   0.13
# 148   0.11
# 149   0.10
# Name: petal_width_perc, Length: 150, dtype: float64
#      sepal_length  sepal_width  petal_length  petal_width
# 0            0.54         0.27          0.15         0.04
# 1            0.49         0.33          0.16         0.02
# 2            0.52         0.32          0.15         0.02
# 3            0.52         0.32          0.15         0.01
# 4            0.51         0.35          0.13         0.01
# ..            ...          ...           ...          ...
# 145          0.36         0.19          0.32         0.14
# 146          0.36         0.20          0.31         0.13
# 147          0.37         0.19          0.31         0.13
# 148          0.38         0.19          0.33         0.11
# 149          0.39         0.19          0.32         0.10
#
# [150 rows x 4 columns]

# %%
# For each column, find the percentage of 
# each value in the sum of the column
# i.e. normalize by column
df1=df.iloc[:,0:4].apply(lambda col: col/sum(col),axis=0)
df1

# note the lambda function cannot be used 
# outside of the apply statement
# you can also assign it to a variable 
# which is the function name!
t=lambda x: x*2
type(t)
t(20)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0            0.01         0.01          0.00         0.00
# 1            0.01         0.01          0.00         0.00
# 2            0.01         0.01          0.00         0.00
# 3            0.01         0.01          0.00         0.00
# 4            0.00         0.01          0.00         0.00
# ..            ...          ...           ...          ...
# 145          0.01         0.01          0.01         0.01
# 146          0.01         0.01          0.01         0.01
# 147          0.01         0.01          0.01         0.01
# 148          0.01         0.01          0.01         0.01
# 149          0.01         0.01          0.01         0.01
#
# [150 rows x 4 columns]
# function
# 40

# %% [markdown]
# ### 3.7.  DataFrame concatenate and join
# - Dataframes can flexibly concatenated or joined

# %%
# Exercise 3.7.1  Concatenate two dateframes
df1 = pd.DataFrame(np.random.randint(0,10, size=(3,2)), \
                   columns=['A','B'])
df1

df2 = pd.DataFrame(np.random.randint(0,10, size=(4,2)), \
                   columns=['A','C'])
df2

# Concatenate two dataframes
pd.concat([df1, df2])

# the new dataframe will have columns A,B,C
# but some portion is NaN (Null)
# Out:
#    A  B
# 0  3  4
# 1  5  3
# 2  8  1
#    A  C
# 0  3  4
# 1  8  6
# 2  3  9
# 3  9  0
#    A    B    C
# 0  3 4.00  NaN
# 1  5 3.00  NaN
# 2  8 1.00  NaN
# 0  3  NaN 4.00
# 1  8  NaN 6.00
# 2  3  NaN 9.00
# 3  9  NaN 0.00

# %%
# Exercise 3.5.2  Merge two dataframes on common columns
#{‘left’, ‘right’, ‘outer’, ‘inner’, ‘cross’}, default ‘inner’
df1
df2
pd.merge(df1, df2, on='A',how="left")

# use "on" to join by a specific column
# use "how" to specify inner or outer join
# Out:
#    A  B
# 0  3  4
# 1  5  3
# 2  8  1
#    A  C
# 0  3  4
# 1  8  6
# 2  3  9
# 3  9  0
#    A  B    C
# 0  3  4 4.00
# 1  3  4 9.00
# 2  5  3  NaN
# 3  8  1 6.00

# %% [markdown]
# ### 3.8. Getting Data In/Out

# %%
# Exercise 3.8.1  getting data in/out 

# write dataframe to a csv with header without index
df.to_csv('foo.csv', header=True, index=True)

# read a csv file to a dataframe
# use the first row as header
data=pd.read_csv('foo.csv', header=0)
data

# convert data to a list
data_list=data.values.tolist()
data_list
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0          4.50         2.30          1.30         0.30
# 1             1          4.40         2.90          1.40         0.20
# 2             2          4.90         3.00          1.40         0.20
# 3             3          4.80         3.00          1.40         0.10
# 4             4          4.30         3.00          1.10         0.10
# ..          ...           ...          ...           ...          ...
# 145         145          6.30         3.40          5.60         2.40
# 146         146          6.20         3.40          5.40         2.30
# 147         147          7.20         3.60          6.10         2.50
# 148         148          7.70         3.80          6.70         2.20
# 149         149          7.90         3.80          6.40         2.00
#
#           type   soil sepal_length_cat  petal_width_perc
# 0       Setosa  Shade       very short              0.04
# 1       Setosa  Shade       very short              0.02
# 2       Setosa  Shade       very short              0.02
# 3       Setosa    Sun       very short              0.01
# 4       Setosa    Sun       very short              0.01
# ..         ...    ...              ...               ...
# 145  Virginica  Shade             long              0.14
# 146  Virginica  Shade             long              0.13
# 147  Virginica  Shade        very long              0.13
# 148  Virginica  Shade        very long              0.11
# 149  Virginica  Shade        very long              0.10
#
# [150 rows x 9 columns]
# [[0, 4.5, 2.3, 1.3, 0.3, 'Setosa', 'Shade', 'very short', 0.0357142857142857],
#  [1, 4.4, 2.9, 1.4, 0.2, 'Setosa', 'Shade', 'very short', 0.0224719101123595],
#  [2, 4.9, 3.0, 1.4, 0.2, 'Setosa', 'Shade', 'very short', 0.0210526315789473],
#  [3, 4.8, 3.0, 1.4, 0.1, 'Setosa', 'Sun', 'very short', 0.010752688172043],
#  [4, 4.3, 3.0, 1.1, 0.1, 'Setosa', 'Sun', 'very short', 0.0117647058823529],
#  [5, 5.0, 3.0, 1.6, 0.2, 'Setosa', 'Sun', 'very short', 0.0204081632653061],
#  [6, 4.4, 3.0, 1.3, 0.2, 'Setosa', 'Sun', 'very short', 0.0224719101123595],
#  [7, 4.8, 3.0, 1.4, 0.3, 'Setosa', 'Sun', 'very short', 0.031578947368421],
#  [8, 4.6, 3.1, 1.5, 0.2, 'Setosa', 'Shade', 'very short', 0.0212765957446808],
#  [9, 4.9, 3.1, 1.5, 0.1, 'Setosa', 'Sun', 'very short', 0.0104166666666666],
#  [10, 4.8, 3.1, 1.6, 0.2, 'Setosa', 'Sun', 'very short', 0.0206185567010309],
#  [11, 4.9, 3.1, 1.5, 0.2, 'Setosa', 'Shade', 'very short', 0.0206185567010309],
#  [12, 4.7, 3.2, 1.3, 0.2, 'Setosa', 'Sun', 'very short', 0.0212765957446808],
#  [13, 4.7, 3.2, 1.6, 0.2, 'Setosa', 'Sun', 'very short', 0.0206185567010309],
#  [14, 5.0, 3.2, 1.2, 0.2, 'Setosa', 'Shade', 'very short', 0.0208333333333333],
#  [15, 4.4, 3.2, 1.3, 0.2, 'Setosa', 'Sun', 'very short', 0.0219780219780219],
#  [16, 4.6, 3.2, 1.4, 0.2, 'Setosa', 'Sun', 'very short', 0.0212765957446808],
#  [17, 5.1, 3.3, 1.7, 0.5, 'Setosa', 'Shade', 'very short', 0.0471698113207547],
#  [18, 5.0, 3.3, 1.4, 0.2, 'Setosa', 'Sun', 'very short', 0.0202020202020202],
#  [19, 4.6, 3.4, 1.4, 0.3, 'Setosa', 'Shade', 'very short', 0.0309278350515463],
#  [20, 5.0, 3.4, 1.5, 0.2, 'Setosa', 'Shade', 'very short', 0.0198019801980198],
#  [21, 4.8, 3.4, 1.6, 0.2, 'Setosa', 'Shade', 'very short', 0.02],
#  [22, 5.4, 3.4, 1.7, 0.2, 'Setosa', 'Shade', 'short', 0.0186915887850467],
#  [23, 4.8, 3.4, 1.9, 0.2, 'Setosa', 'Sun', 'very short', 0.0194174757281553],
#  [24, 5.0, 3.4, 1.6, 0.4, 'Setosa', 'Sun', 'very short', 0.0384615384615384],
#  [25, 5.2, 3.4, 1.4, 0.2, 'Setosa', 'Sun', 'short', 0.0196078431372549],
#  [26, 5.4, 3.4, 1.5, 0.4, 'Setosa', 'Sun', 'short', 0.0373831775700934],
#  [27, 5.1, 3.4, 1.5, 0.2, 'Setosa', 'Shade', 'very short', 0.0196078431372549],
#  [28, 5.1, 3.5, 1.4, 0.2, 'Setosa', 'Sun', 'very short', 0.0196078431372549],
#  [29, 5.1, 3.5, 1.4, 0.3, 'Setosa', 'Shade', 'very short', 0.029126213592233],
#  [30, 5.2, 3.5, 1.5, 0.2, 'Setosa', 'Shade', 'short', 0.0192307692307692],
#  [31, 5.5, 3.5, 1.3, 0.2, 'Setosa', 'Shade', 'short', 0.019047619047619],
#  [32, 5.0, 3.5, 1.3, 0.3, 'Setosa', 'Shade', 'very short', 0.0297029702970296],
#  [33, 5.0, 3.5, 1.6, 0.6, 'Setosa', 'Sun', 'very short', 0.0560747663551401],
#  [34, 5.0, 3.6, 1.4, 0.2, 'Setosa', 'Shade', 'very short', 0.0196078431372549],
#  [35, 4.6, 3.6, 1.0, 0.2, 'Setosa', 'Shade', 'very short', 0.0212765957446808],
#  [36, 4.9, 3.6, 1.4, 0.1, 'Setosa', 'Sun', 'very short', 0.01],
#  [37, 5.4, 3.7, 1.5, 0.2, 'Setosa', 'Sun', 'short', 0.0185185185185185],
#  [38, 5.1, 3.7, 1.5, 0.4, 'Setosa', 'Sun', 'very short', 0.0373831775700934],
#  [39, 5.3, 3.7, 1.5, 0.2, 'Setosa', 'Shade', 'short', 0.0186915887850467],
#  [40, 5.7, 3.8, 1.7, 0.3, 'Setosa', 'Sun', 'short', 0.0260869565217391],
#  [41, 5.1, 3.8, 1.5, 0.3, 'Setosa', 'Sun', 'very short', 0.02803738317757],
#  [42, 5.1, 3.8, 1.9, 0.4, 'Setosa', 'Shade', 'very short', 0.0357142857142857],
#  [43, 5.1, 3.8, 1.6, 0.2, 'Setosa', 'Sun', 'very short', 0.0186915887850467],
#  [44, 5.4, 3.9, 1.7, 0.4, 'Setosa', 'Sun', 'short', 0.0350877192982456],
#  [45, 5.4, 3.9, 1.3, 0.4, 'Setosa', 'Sun', 'short', 0.0363636363636363],
#  [46, 5.8, 4.0, 1.2, 0.2, 'Setosa', 'Shade', 'short', 0.0178571428571428],
#  [47, 5.2, 4.1, 1.5, 0.1, 'Setosa', 'Sun', 'short', 0.0091743119266055],
#  [48, 5.5, 4.2, 1.4, 0.2, 'Setosa', 'Shade', 'short', 0.0176991150442477],
#  [49, 5.7, 4.4, 1.5, 0.4, 'Setosa', 'Shade', 'short', 0.0333333333333333],
#  [50,
#   5.0,
#   2.0,
#   3.5,
#   1.0,
#   'Versicolour',
#   'Shade',
#   'very short',
#   0.0869565217391304],
#  [51, 6.0, 2.2, 4.0, 1.0, 'Versicolour', 'Shade', 'long', 0.0757575757575757],
#  [52, 6.2, 2.2, 4.5, 1.5, 'Versicolour', 'Shade', 'long', 0.1041666666666666],
#  [53, 5.5, 2.3, 4.0, 1.3, 'Versicolour', 'Shade', 'short', 0.099236641221374],
#  [54, 6.3, 2.3, 4.4, 1.3, 'Versicolour', 'Shade', 'long', 0.0909090909090909],
#  [55,
#   5.0,
#   2.3,
#   3.3,
#   1.0,
#   'Versicolour',
#   'Shade',
#   'very short',
#   0.0862068965517241],
#  [56,
#   4.9,
#   2.4,
#   3.3,
#   1.0,
#   'Versicolour',
#   'Shade',
#   'very short',
#   0.0862068965517241],
#  [57, 5.5, 2.4, 3.8, 1.1, 'Versicolour', 'Shade', 'short', 0.0859375],
#  [58, 5.5, 2.4, 3.7, 1.0, 'Versicolour', 'Shade', 'short', 0.0793650793650793],
#  [59, 5.6, 2.5, 3.9, 1.1, 'Versicolour', 'Shade', 'short', 0.0839694656488549],
#  [60, 6.3, 2.5, 4.9, 1.5, 'Versicolour', 'Shade', 'long', 0.0986842105263157],
#  [61, 5.5, 2.5, 4.0, 1.3, 'Versicolour', 'Shade', 'short', 0.0977443609022556],
#  [62,
#   5.1,
#   2.5,
#   3.0,
#   1.1,
#   'Versicolour',
#   'Shade',
#   'very short',
#   0.094017094017094],
#  [63, 5.7, 2.6, 3.5, 1.0, 'Versicolour', 'Shade', 'short', 0.078125],
#  [64, 5.5, 2.6, 4.4, 1.2, 'Versicolour', 'Sun', 'short', 0.0875912408759124],
#  [65, 5.8, 2.6, 4.0, 1.2, 'Versicolour', 'Shade', 'short', 0.088235294117647],
#  [66, 5.2, 2.7, 3.9, 1.4, 'Versicolour', 'Shade', 'short', 0.106060606060606],
#  [67, 5.8, 2.7, 4.1, 1.0, 'Versicolour', 'Shade', 'short', 0.0735294117647058],
#  [68, 5.8, 2.7, 3.9, 1.2, 'Versicolour', 'Shade', 'short', 0.088235294117647],
#  [69, 6.0, 2.7, 5.1, 1.6, 'Versicolour', 'Shade', 'long', 0.1038961038961039],
#  [70, 5.6, 2.7, 4.2, 1.3, 'Versicolour', 'Sun', 'short', 0.0942028985507246],
#  [71,
#   6.5,
#   2.8,
#   4.6,
#   1.5,
#   'Versicolour',
#   'Sun',
#   'very long',
#   0.0974025974025974],
#  [72, 5.7, 2.8, 4.5, 1.3, 'Versicolour', 'Sun', 'short', 0.0909090909090909],
#  [73, 6.1, 2.8, 4.0, 1.3, 'Versicolour', 'Sun', 'long', 0.0915492957746478],
#  [74, 6.1, 2.8, 4.7, 1.2, 'Versicolour', 'Shade', 'long', 0.0810810810810811],
#  [75,
#   6.8,
#   2.8,
#   4.8,
#   1.4,
#   'Versicolour',
#   'Shade',
#   'very long',
#   0.0886075949367088],
#  [76, 5.7, 2.8, 4.1, 1.3, 'Versicolour', 'Sun', 'short', 0.0935251798561151],
#  [77,
#   6.6,
#   2.9,
#   4.6,
#   1.3,
#   'Versicolour',
#   'Sun',
#   'very long',
#   0.0844155844155844],
#  [78, 6.1, 2.9, 4.7, 1.4, 'Versicolour', 'Sun', 'long', 0.0927152317880794],
#  [79, 5.6, 2.9, 3.6, 1.3, 'Versicolour', 'Shade', 'short', 0.0970149253731343],
#  [80, 6.4, 2.9, 4.3, 1.3, 'Versicolour', 'Sun', 'long', 0.0872483221476509],
#  [81, 6.0, 2.9, 4.5, 1.5, 'Versicolour', 'Sun', 'long', 0.1006711409395973],
#  [82, 5.7, 2.9, 4.2, 1.3, 'Versicolour', 'Shade', 'short', 0.0921985815602836],
#  [83, 6.2, 2.9, 4.3, 1.3, 'Versicolour', 'Sun', 'long', 0.0884353741496598],
#  [84, 5.9, 3.0, 4.2, 1.5, 'Versicolour', 'Shade', 'long', 0.1027397260273972],
#  [85, 5.6, 3.0, 4.5, 1.5, 'Versicolour', 'Sun', 'short', 0.1027397260273972],
#  [86,
#   6.6,
#   3.0,
#   4.4,
#   1.4,
#   'Versicolour',
#   'Sun',
#   'very long',
#   0.0909090909090909],
#  [87,
#   6.7,
#   3.0,
#   5.0,
#   1.7,
#   'Versicolour',
#   'Sun',
#   'very long',
#   0.1036585365853658],
#  [88, 5.4, 3.0, 4.5, 1.5, 'Versicolour', 'Sun', 'short', 0.1041666666666666],
#  [89, 5.6, 3.0, 4.1, 1.3, 'Versicolour', 'Sun', 'short', 0.0928571428571428],
#  [90, 6.1, 3.0, 4.6, 1.4, 'Versicolour', 'Sun', 'long', 0.0927152317880794],
#  [91, 5.7, 3.0, 4.2, 1.2, 'Versicolour', 'Sun', 'short', 0.0851063829787234],
#  [92,
#   6.9,
#   3.1,
#   4.9,
#   1.5,
#   'Versicolour',
#   'Sun',
#   'very long',
#   0.0914634146341463],
#  [93,
#   6.7,
#   3.1,
#   4.4,
#   1.4,
#   'Versicolour',
#   'Sun',
#   'very long',
#   0.0897435897435897],
#  [94, 6.7, 3.1, 4.7, 1.5, 'Versicolour', 'Sun', 'very long', 0.09375],
#  [95,
#   7.0,
#   3.2,
#   4.7,
#   1.4,
#   'Versicolour',
#   'Sun',
#   'very long',
#   0.0858895705521472],
#  [96, 6.4, 3.2, 4.5, 1.5, 'Versicolour', 'Sun', 'long', 0.0961538461538461],
#  [97, 5.9, 3.2, 4.8, 1.8, 'Versicolour', 'Sun', 'long', 0.1146496815286624],
#  [98, 6.3, 3.3, 4.7, 1.6, 'Versicolour', 'Sun', 'long', 0.10062893081761],
#  [99, 6.0, 3.4, 4.5, 1.6, 'Versicolour', 'Sun', 'long', 0.1032258064516129],
#  [100, 6.0, 2.2, 5.0, 1.5, 'Virginica', 'Sun', 'long', 0.1020408163265306],
#  [101, 4.9, 2.5, 4.5, 1.7, 'Virginica', 'Sun', 'very short', 0.125],
#  [102,
#   6.7,
#   2.5,
#   5.8,
#   1.8,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1071428571428571],
#  [103, 5.7, 2.5, 5.0, 2.0, 'Virginica', 'Sun', 'short', 0.131578947368421],
#  [104, 6.3, 2.5, 5.0, 1.9, 'Virginica', 'Sun', 'long', 0.1210191082802547],
#  [105,
#   7.7,
#   2.6,
#   6.9,
#   2.3,
#   'Virginica',
#   'Sun',
#   'very long',
#   0.1179487179487179],
#  [106, 6.1, 2.6, 5.6, 1.4, 'Virginica', 'Sun', 'long', 0.0891719745222929],
#  [107, 5.8, 2.7, 5.1, 1.9, 'Virginica', 'Sun', 'short', 0.1225806451612903],
#  [108, 6.4, 2.7, 5.3, 1.9, 'Virginica', 'Sun', 'long', 0.1165644171779141],
#  [109, 6.3, 2.7, 4.9, 1.8, 'Virginica', 'Sun', 'long', 0.1146496815286624],
#  [110, 5.8, 2.7, 5.1, 1.9, 'Virginica', 'Sun', 'short', 0.1225806451612903],
#  [111, 5.8, 2.8, 5.1, 2.4, 'Virginica', 'Sun', 'short', 0.1490683229813664],
#  [112, 5.6, 2.8, 4.9, 2.0, 'Virginica', 'Sun', 'short', 0.130718954248366],
#  [113,
#   7.7,
#   2.8,
#   6.7,
#   2.0,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1041666666666666],
#  [114, 6.2, 2.8, 4.8, 1.8, 'Virginica', 'Sun', 'long', 0.1153846153846153],
#  [115, 6.4, 2.8, 5.6, 2.1, 'Virginica', 'Shade', 'long', 0.1242603550295858],
#  [116,
#   7.4,
#   2.8,
#   6.1,
#   1.9,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1043956043956044],
#  [117, 6.4, 2.8, 5.6, 2.2, 'Virginica', 'Shade', 'long', 0.1294117647058823],
#  [118, 6.3, 2.8, 5.1, 1.5, 'Virginica', 'Shade', 'long', 0.0955414012738853],
#  [119, 6.3, 2.9, 5.6, 1.8, 'Virginica', 'Sun', 'long', 0.108433734939759],
#  [120,
#   7.3,
#   2.9,
#   6.3,
#   1.8,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.0983606557377049],
#  [121,
#   7.1,
#   3.0,
#   5.9,
#   2.1,
#   'Virginica',
#   'Sun',
#   'very long',
#   0.1160220994475138],
#  [122,
#   6.5,
#   3.0,
#   5.8,
#   2.2,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1257142857142857],
#  [123,
#   7.6,
#   3.0,
#   6.6,
#   2.1,
#   'Virginica',
#   'Sun',
#   'very long',
#   0.1088082901554404],
#  [124,
#   6.8,
#   3.0,
#   5.5,
#   2.1,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1206896551724137],
#  [125,
#   6.5,
#   3.0,
#   5.5,
#   1.8,
#   'Virginica',
#   'Sun',
#   'very long',
#   0.1071428571428571],
#  [126, 6.1, 3.0, 4.9, 1.8, 'Virginica', 'Sun', 'long', 0.1139240506329113],
#  [127,
#   7.2,
#   3.0,
#   5.8,
#   1.6,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.0909090909090909],
#  [128,
#   7.7,
#   3.0,
#   6.1,
#   2.3,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1204188481675392],
#  [129, 6.0, 3.0, 4.8, 1.8, 'Virginica', 'Shade', 'long', 0.1153846153846153],
#  [130,
#   6.7,
#   3.0,
#   5.2,
#   2.3,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1337209302325581],
#  [131,
#   6.5,
#   3.0,
#   5.2,
#   2.0,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1197604790419161],
#  [132, 5.9, 3.0, 5.1, 1.8, 'Virginica', 'Shade', 'long', 0.1139240506329113],
#  [133, 6.4, 3.1, 5.5, 1.8, 'Virginica', 'Shade', 'long', 0.1071428571428571],
#  [134, 6.9, 3.1, 5.4, 2.1, 'Virginica', 'Shade', 'very long', 0.12],
#  [135,
#   6.7,
#   3.1,
#   5.6,
#   2.4,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1348314606741573],
#  [136,
#   6.9,
#   3.1,
#   5.1,
#   2.3,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.132183908045977],
#  [137,
#   6.5,
#   3.2,
#   5.1,
#   2.0,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.119047619047619],
#  [138, 6.4, 3.2, 5.3, 2.3, 'Virginica', 'Sun', 'long', 0.1337209302325581],
#  [139,
#   6.9,
#   3.2,
#   5.7,
#   2.3,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1270718232044198],
#  [140,
#   7.2,
#   3.2,
#   6.0,
#   1.8,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.0989010989010989],
#  [141,
#   6.8,
#   3.2,
#   5.9,
#   2.3,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1263736263736263],
#  [142, 6.3, 3.3, 6.0, 2.5, 'Virginica', 'Shade', 'long', 0.1381215469613259],
#  [143,
#   6.7,
#   3.3,
#   5.7,
#   2.1,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1179775280898876],
#  [144,
#   6.7,
#   3.3,
#   5.7,
#   2.5,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1373626373626373],
#  [145, 6.3, 3.4, 5.6, 2.4, 'Virginica', 'Shade', 'long', 0.135593220338983],
#  [146, 6.2, 3.4, 5.4, 2.3, 'Virginica', 'Shade', 'long', 0.1329479768786127],
#  [147,
#   7.2,
#   3.6,
#   6.1,
#   2.5,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1288659793814433],
#  [148,
#   7.7,
#   3.8,
#   6.7,
#   2.2,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.1078431372549019],
#  [149,
#   7.9,
#   3.8,
#   6.4,
#   2.0,
#   'Virginica',
#   'Shade',
#   'very long',
#   0.099502487562189]]
